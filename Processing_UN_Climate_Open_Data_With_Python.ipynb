# %%
import sys
sys.version
# Out:
# '2.7.11 (default, Jan 22 2016, 08:28:37) \n[GCC 4.2.1 Compatible Apple LLVM 7.0.2 (clang-700.1.81)]'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# u'0.18.0'

# %%
# !ls
# Out:
# 20160524-python-data-processing.ipynb             outofschoolchildren.csv
# Processing_UN_Climate_Open_Data_With_Python.ipynb pclassadult_sex.pdf
# README.md                                         pclassage_sex.pdf
# Untitled.ipynb                                    pivot_table_data_viz.ipynb
# countries_metadata.csv                            total_children_by_year.pdf
# data                                              workshop1_pandas_titanic.md
# figure1.pdf                                       workshop2_pivot_table_and_data_viz.ipynb

# %% [markdown]
# <h2, align=center>Getting and Importing Data</h2>

# %% [markdown]
# ### What do you want to know from the data?

# %% [markdown]
# #### CO2 Data can be downloaded from The World Bank website
# #### http://data.worldbank.org/indicator/EN.ATM.CO2E.PC/
# #### Population Data
# #### http://data.worldbank.org/indicator/SP.POP.TOTL

# %% [markdown]
# Visual check before importing the data

# %%
df_co2 = pd.read_csv(
    "data/co2_aac3f2a3-99c7-4ea6-a6ef-32ead3d3dbfe_v2/aac3f2a3-99c7-4ea6-a6ef-32ead3d3dbfe_v2.csv",
    skiprows = 4,
    encoding = "utf-8"
)

# %% [markdown]
# #### Tidy Data
# #### Data Quality Checklist

# %% [markdown]
# ## Dataframe and Subsetting
# #### Dataframe attributes

# %%
type(df_co2)
# Out:
# pandas.core.frame.DataFrame

# %%
df_co2.shape
# Out:
# (248, 61)

# %%
df_co2.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
# 1961              float64
# 1962              float64
# 1963              float64
# 1964              float64
# 1965              float64
# 1966              float64
# 1967              float64
# 1968              float64
# 1969              float64
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
#                    ...
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# 1991              float64
# 1992              float64
# 1993              float64
# 1994              float64
# 1995              float64
# 1996              float64
# 1997              float64
# 1998              float64
# 1999              float64
# 2000              float64
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# Unnamed: 60       float64
# dtype: object

# %%
df_co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 61 columns):
# Country Name      248 non-null object
# Country Code      248 non-null object
# Indicator Name    248 non-null object
# Indicator Code    248 non-null object
# 1960              178 non-null float64
# 1961              179 non-null float64
# 1962              180 non-null float64
# 1963              181 non-null float64
# 1964              186 non-null float64
# 1965              186 non-null float64
# 1966              186 non-null float64
# 1967              186 non-null float64
# 1968              185 non-null float64
# 1969              186 non-null float64
# 1970              188 non-null float64
# 1971              189 non-null float64
# 1972              192 non-null float64
# 1973              192 non-null float64
# 1974              192 non-null float64
# 1975              192 non-null float64
# 1976              192 non-null float64
# 1977              192 non-null float64
# 1978              192 non-null float64
# 1979              192 non-null float64
# 1980              192 non-null float64
# 1981              192 non-null float64
# 1982              192 non-null float64
# 1983              192 non-null float64
# 1984              192 non-null float64
# 1985              192 non-null float64
# 1986              193 non-null float64
# 1987              193 non-null float64
# 1988              193 non-null float64
# 1989              193 non-null float64
# 1990              195 non-null float64
# 1991              196 non-null float64
# 1992              219 non-null float64
# 1993              219 non-null float64
# 1994              220 non-null float64
# 1995              223 non-null float64
# 1996              222 non-null float64
# 1997              224 non-null float64
# 1998              226 non-null float64
# 1999              226 non-null float64
# 2000              227 non-null float64
# 2001              227 non-null float64
# 2002              228 non-null float64
# 2003              228 non-null float64
# 2004              228 non-null float64
# 2005              230 non-null float64
# 2006              231 non-null float64
# 2007              232 non-null float64
# 2008              232 non-null float64
# 2009              232 non-null float64
# 2010              232 non-null float64
# 2011              232 non-null float64
# 2012              0 non-null float64
# 2013              0 non-null float64
# 2014              0 non-null float64
# 2015              0 non-null float64
# Unnamed: 60       0 non-null float64
# dtypes: float64(57), object(4)
# memory usage: 118.3+ KB

# %%
df_co2
# Out:
#                        Country Name Country Code  \
# 0                             Aruba          ABW
# 1                           Andorra          AND
# 2                       Afghanistan          AFG
# 3                            Angola          AGO
# 4                           Albania          ALB
# 5                        Arab World          ARB
# 6              United Arab Emirates          ARE
# 7                         Argentina          ARG
# 8                           Armenia          ARM
# 9                    American Samoa          ASM
# 10              Antigua and Barbuda          ATG
# 11                        Australia          AUS
# 12                          Austria          AUT
# 13                       Azerbaijan          AZE
# 14                          Burundi          BDI
# 15                          Belgium          BEL
# 16                            Benin          BEN
# 17                     Burkina Faso          BFA
# 18                       Bangladesh          BGD
# 19                         Bulgaria          BGR
# 20                          Bahrain          BHR
# 21                     Bahamas, The          BHS
# 22           Bosnia and Herzegovina          BIH
# 23                          Belarus          BLR
# 24                           Belize          BLZ
# 25                          Bermuda          BMU
# 26                          Bolivia          BOL
# 27                           Brazil          BRA
# 28                         Barbados          BRB
# 29                Brunei Darussalam          BRN
# ..                              ...          ...
# 218                            Togo          TGO
# 219                        Thailand          THA
# 220                      Tajikistan          TJK
# 221                    Turkmenistan          TKM
# 222                     Timor-Leste          TLS
# 223                           Tonga          TON
# 224             Trinidad and Tobago          TTO
# 225                         Tunisia          TUN
# 226                          Turkey          TUR
# 227                          Tuvalu          TUV
# 228                        Tanzania          TZA
# 229                          Uganda          UGA
# 230                         Ukraine          UKR
# 231             Upper middle income          UMC
# 232                         Uruguay          URY
# 233                   United States          USA
# 234                      Uzbekistan          UZB
# 235  St. Vincent and the Grenadines          VCT
# 236                   Venezuela, RB          VEN
# 237           Virgin Islands (U.S.)          VIR
# 238                         Vietnam          VNM
# 239                         Vanuatu          VUT
# 240              West Bank and Gaza          PSE
# 241                           World          WLD
# 242                           Samoa          WSM
# 243                     Yemen, Rep.          YEM
# 244                    South Africa          ZAF
# 245                Congo, Dem. Rep.          COD
# 246                          Zambia          ZMB
# 247                        Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.046068
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.104357
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.643964
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.118786
# 7    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.367473
# 8    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 9    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 10   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.670617
# 11   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   8.582937
# 12   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.373319
# 13   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 14   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 15   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   9.941594
# 16   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.066354
# 17   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.009112
# 18   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.833901
# 20   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.542864
# 21   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.749831
# 22   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 23   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 24   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.477951
# 25   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.551374
# 26   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.272038
# 27   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.647068
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.746313
# 29   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.078179
# ..                                      ...             ...        ...
# 218  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.041762
# 219  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135586
# 220  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 221  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 222  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 223  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.178588
# 224  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.042576
# 225  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.409211
# 226  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.610473
# 227  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 228  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.082261
# 229  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.062123
# 230  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 231  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.288256
# 232  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.701583
# 233  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  15.999779
# 234  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 235  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135902
# 236  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   7.005107
# 237  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 238  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.215631
# 239  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 240  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 241  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.096144
# 242  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135009
# 243  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.703403
# 244  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   5.629718
# 245  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.152228
# 246  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 247  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
#
#           1961       1962       1963       1964       1965     ...       \
# 0          NaN        NaN        NaN        NaN        NaN     ...
# 1          NaN        NaN        NaN        NaN        NaN     ...
# 2     0.053615   0.073781   0.074251   0.086317   0.101499     ...
# 3     0.084718   0.216025   0.206877   0.216174   0.206089     ...
# 4     1.374186   1.439956   1.181681   1.111742   1.166099     ...
# 5     0.685501   0.761148   0.875124   0.999248   1.166075     ...
# 6     0.108937   0.163355   0.175712   0.132651   0.146370     ...
# 7     2.442616   2.522392   2.316356   2.538380   2.641714     ...
# 8          NaN        NaN        NaN        NaN        NaN     ...
# 9          NaN        NaN        NaN        NaN        NaN     ...
# 10    0.860441   1.823374   1.470175   1.567094   2.520359     ...
# 11    8.641569   8.835688   9.226440   9.759073  10.622321     ...
# 12    4.496362   4.755362   5.155194   5.391004   5.252197     ...
# 13         NaN        NaN        NaN        NaN        NaN     ...
# 14         NaN   0.015203   0.016155   0.015827   0.011910     ...
# 15   10.103872  10.641190  11.386929  11.053655  11.141656     ...
# 16    0.052046   0.054202   0.047580   0.055295   0.057115     ...
# 17    0.018730   0.017003   0.017504   0.021575   0.019841     ...
# 18         NaN        NaN        NaN        NaN        NaN     ...
# 19    3.269920   3.835892   4.259781   5.262988   5.645652     ...
# 20   10.547396   9.193609   6.714156   8.747480   6.557022     ...
# 21    4.746699   5.996432   5.558199   8.118597   9.399946     ...
# 22         NaN        NaN        NaN        NaN        NaN     ...
# 23         NaN        NaN        NaN        NaN        NaN     ...
# 24    0.387219   0.715409   0.622357   0.818289   0.794763     ...
# 25    3.868484   3.383712   3.151929   4.124438   3.586487     ...
# 26    0.276621   0.286626   0.310159   0.371216   0.371151     ...
# 27    0.658625   0.697281   0.700749   0.694001   0.670372     ...
# 28    0.838899   1.119411   0.816330   0.766085   0.872454     ...
# 29    3.552009   4.133422   3.798174   3.482289   3.254787     ...
# ..         ...        ...        ...        ...        ...     ...
# 218   0.057386   0.054570   0.065171   0.079426   0.077262     ...
# 219   0.146944   0.173130   0.185877   0.242240   0.234151     ...
# 220        NaN        NaN        NaN        NaN        NaN     ...
# 221        NaN        NaN        NaN        NaN        NaN     ...
# 245   0.047312   0.048411   0.045604   0.049328   0.050303   NaN   NaN   NaN
# 246   0.150265   0.164692   0.184058   0.192079   0.212450   NaN   NaN   NaN
# 247   0.731867   0.569255   0.600521   0.646073   0.691698   NaN   NaN   NaN
#
#      2015  Unnamed: 60
# 0     NaN          NaN
# 1     NaN          NaN
# 2     NaN          NaN
# 3     NaN          NaN
# 4     NaN          NaN
# 5     NaN          NaN
# 6     NaN          NaN
# 7     NaN          NaN
# 8     NaN          NaN
# 9     NaN          NaN
# 10    NaN          NaN
# 11    NaN          NaN
# 12    NaN          NaN
# 13    NaN          NaN
# 14    NaN          NaN
# 15    NaN          NaN
# 16    NaN          NaN
# 17    NaN          NaN
# 18    NaN          NaN
# 19    NaN          NaN
# 20    NaN          NaN
# 21    NaN          NaN
# 22    NaN          NaN
# 23    NaN          NaN
# 24    NaN          NaN
# 25    NaN          NaN
# 26    NaN          NaN
# 27    NaN          NaN
# 28    NaN          NaN
# 29    NaN          NaN
# ..    ...          ...
# 218   NaN          NaN
# 219   NaN          NaN
# 220   NaN          NaN
# 221   NaN          NaN
# 222   NaN          NaN
# 223   NaN          NaN
# 224   NaN          NaN
# 225   NaN          NaN
# 226   NaN          NaN
# 227   NaN          NaN
# 228   NaN          NaN
# 229   NaN          NaN
# 230   NaN          NaN
# 231   NaN          NaN
# 232   NaN          NaN
# 233   NaN          NaN
# 234   NaN          NaN
# 235   NaN          NaN
# 236   NaN          NaN
# 237   NaN          NaN
# 238   NaN          NaN
# 239   NaN          NaN
# 240   NaN          NaN
# 241   NaN          NaN
# 242   NaN          NaN
# 243   NaN          NaN
# 244   NaN          NaN
# 245   NaN          NaN
# 246   NaN          NaN
# 247   NaN          NaN
#
# [248 rows x 61 columns]

# %%
df_co2.head()
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1      Andorra          AND  CO2 emissions (metric tons per capita)
# 2  Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 3       Angola          AGO  CO2 emissions (metric tons per capita)
# 4      Albania          ALB  CO2 emissions (metric tons per capita)
#
#    Indicator Code      1960      1961      1962      1963      1964      1965  \
# 0  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 1  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 2  EN.ATM.CO2E.PC  0.046068  0.053615  0.073781  0.074251  0.086317  0.101499
# 3  EN.ATM.CO2E.PC  0.104357  0.084718  0.216025  0.206877  0.216174  0.206089
# 4  EN.ATM.CO2E.PC  1.258195  1.374186  1.439956  1.181681  1.111742  1.166099
#
#       ...            2007       2008       2009       2010       2011  2012  \
# 0     ...       25.613715  24.750133  24.876706  24.182702  23.922412   NaN
# 1     ...        6.350868   6.296125   6.049173   6.124770   5.968685   NaN
# 2     ...        0.088141   0.158962   0.249074   0.302936   0.425262   NaN
# 3     ...        1.311096   1.369425   1.430873   1.401654   1.354008   NaN
# 4     ...        1.507536   1.580113   1.533178   1.515632   1.607038   NaN
#
#    2013  2014  2015  Unnamed: 60
# 0   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN          NaN
# 3   NaN   NaN   NaN          NaN
# 4   NaN   NaN   NaN          NaN
#
# [5 rows x 61 columns]

# %%
df_co2.head?

# %% [markdown]
# #### Exercise: show the first 3 rows of this dataframe

# %%
dir(df_co2)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__unicode__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_only_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_align_frame',
#  '_align_series',
#  '_apply_broadcast',
#  '_apply_empty_result',
#  '_apply_raw',
#  '_apply_standard',
#  '_at',
#  '_box_col_values',
#  '_box_item_values',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_percentile',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_combine_const',
#  '_combine_frame',
#  '_combine_match_columns',
#  '_combine_match_index',
#  '_combine_series',
#  '_combine_series_infer',
#  '_compare_frame',
#  '_compare_frame_evaluate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_dict_for_slice',
#  '_construct_axes_dict_from',
#  '_construct_axes_from_arguments',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_create_indexer',
#  '_dir_additions',
#  '_dir_deletions',
#  '_ensure_valid_index',
#  '_expand_axes',
#  '_flex_compare_frame',
#  '_from_arrays',
#  '_from_axes',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_numeric_data',
#  '_get_values',
#  '_getitem_array',
#  '_getitem_column',
#  '_getitem_frame',
#  '_getitem_multilevel',
#  '_getitem_slice',
#  '_iat',
#  '_iget_item_cache',
#  '_iloc',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_dict',
#  '_init_mgr',
#  '_init_ndarray',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_cached',
#  '_is_datelike_mixed_type',
#  '_is_mixed_type',
#  '_is_numeric_mixed_type',
#  '_is_view',
#  '_ix',
#  '_ixs',
#  '_join_compat',
#  '_loc',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_nsorted',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_axis',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_setup_axes',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_typ',
#  '_unpickle_frame_compat',
#  '_unpickle_matrix_compat',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_xs',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'as_blocks',
#  'as_matrix',
#  'asfreq',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'axes',
#  'between_time',
#  'bfill',
#  'blocks',
#  'bool',
#  'boxplot',
#  'clip',
#  'clip_lower',
#  'clip_upper',
#  'columns',
#  'combine',
#  'combineAdd',
#  'combineMult',
#  'combine_first',
#  'compound',
#  'consolidate',
#  'convert_objects',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'from_csv',
#  'from_dict',
#  'from_items',
#  'from_records',
#  'ftypes',
#  'ge',
#  'get',
#  'get_dtype_counts',
#  'get_ftype_counts',
#  'get_value',
#  'get_values',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'icol',
#  'idxmax',
#  'idxmin',
#  'iget_value',
#  'iloc',
#  'index',
#  'info',
#  'insert',
#  'interpolate',
#  'irow',
#  'is_copy',
#  'isin',
#  'isnull',
#  'iteritems',
#  'iterkv',
#  'iterrows',
#  'itertuples',
#  'ix',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notnull',
#  'nsmallest',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_axis',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_index',
#  'set_value',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort',
#  'sort_index',
#  'sort_values',
#  'sortlevel',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dense',
#  'to_dict',
#  'to_excel',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_msgpack',
#  'to_panel',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sparse',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_wide',
#  'to_xarray',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tshift',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
help(df_co2.shift)
# Out:
# Help on method shift in module pandas.core.frame:
#
# shift(self, periods=1, freq=None, axis=0) method of pandas.core.frame.DataFrame instance
#     Shift index by desired number of periods with an optional time freq
#
#     Parameters
#     ----------
#     periods : int
#         Number of periods to move, can be positive or negative
#     freq : DateOffset, timedelta, or time rule string, optional
#         Increment to use from datetools module or time rule (e.g. 'EOM').
#         See Notes.
#     axis : {0, 1, 'index', 'columns'}
#
#     Notes
#     -----
#     If freq is specified then the index values are shifted but the data
#     is not realigned. That is, use freq if you would like to extend the
#     index when shifting and preserve the original data.
#
#     Returns
#     -------
#     shifted : DataFrame

# %%
df_co2.columns
# Out:
# Index([  u'Country Name',   u'Country Code', u'Indicator Name',
#        u'Indicator Code',           u'1960',           u'1961',
#                  u'1962',           u'1963',           u'1964',
#                  u'1965',           u'1966',           u'1967',
#                  u'1968',           u'1969',           u'1970',
#                  u'1971',           u'1972',           u'1973',
#                  u'1974',           u'1975',           u'1976',
#                  u'1977',           u'1978',           u'1979',
#                  u'1980',           u'1981',           u'1982',
#                  u'1983',           u'1984',           u'1985',
#                  u'1986',           u'1987',           u'1988',
#                  u'1989',           u'1990',           u'1991',
#                  u'1992',           u'1993',           u'1994',
#                  u'1995',           u'1996',           u'1997',
#                  u'1998',           u'1999',           u'2000',
#                  u'2001',           u'2002',           u'2003',
#                  u'2004',           u'2005',           u'2006',
#                  u'2007',           u'2008',           u'2009',
#                  u'2010',           u'2011',           u'2012',
#                  u'2013',           u'2014',           u'2015',
#           u'Unnamed: 60'],
#       dtype='object')

# %%
df_co2.columns[0]
# Out:
# u'Country Name'

# %%
#Indexing in Python
list1 = [1,2,3,4,5]
first_element = list1[0]
second_element = list1[1]
last_element = list1[-1]
print(first_element)
print(second_element)
print(last_element)
# Out:
# 1
# 2
# 5

# %% [markdown]
# ## Subsetting

# %%
#select columns
#by name
df_co2['Country Name'].head()
# Out:
# 0          Aruba
# 1        Andorra
# 2    Afghanistan
# 3         Angola
# 4        Albania
# Name: Country Name, dtype: object

# %%
df_co2[['Country Name', 'Country Code']].head()
# Out:
#   Country Name Country Code
# 0        Aruba          ABW
# 1      Andorra          AND
# 2  Afghanistan          AFG
# 3       Angola          AGO
# 4      Albania          ALB

# %% [markdown]
# ### Exercise: show the first 2 rows of the column named 1960

# %%
#select rows
df_co2[0:2]
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1      Andorra          AND  CO2 emissions (metric tons per capita)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965     ...            2007  \
# 0  EN.ATM.CO2E.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...       25.613715
# 1  EN.ATM.CO2E.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...        6.350868
#
#         2008       2009       2010       2011  2012  2013  2014  2015  \
# 0  24.750133  24.876706  24.182702  23.922412   NaN   NaN   NaN   NaN
# 1   6.296125   6.049173   6.124770   5.968685   NaN   NaN   NaN   NaN
#
#    Unnamed: 60
# 0          NaN
# 1          NaN
#
# [2 rows x 61 columns]

# %% [markdown]
# #### pay attention to 0:2

# %%
#select row and columns
df_co2['Country Name'][0:2]
# Out:
# 0      Aruba
# 1    Andorra
# Name: Country Name, dtype: object

# %% [markdown]
# #### better ways to subset

# %%
#loc uses row column strings 
df_co2.loc[0:2]
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1      Andorra          AND  CO2 emissions (metric tons per capita)
# 2  Afghanistan          AFG  CO2 emissions (metric tons per capita)
#
#    Indicator Code      1960      1961      1962      1963      1964      1965  \
# 0  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 1  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 2  EN.ATM.CO2E.PC  0.046068  0.053615  0.073781  0.074251  0.086317  0.101499
#
#       ...            2007       2008       2009       2010       2011  2012  \
# 0     ...       25.613715  24.750133  24.876706  24.182702  23.922412   NaN
# 1     ...        6.350868   6.296125   6.049173   6.124770   5.968685   NaN
# 2     ...        0.088141   0.158962   0.249074   0.302936   0.425262   NaN
#
#    2013  2014  2015  Unnamed: 60
# 0   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN          NaN
#
# [3 rows x 61 columns]

# %%
df_co2.loc[0:2,'Country Name']
# Out:
# 0          Aruba
# 1        Andorra
# 2    Afghanistan
# Name: Country Name, dtype: object

# %%
#iloc uses only index position
df_co2.iloc[0:2, 0]
# Out:
# 0      Aruba
# 1    Andorra
# Name: Country Name, dtype: object

# %%
#ix uses a mix of row index and column labels
df_co2.ix[0:2, 'Country Name']
# Out:
# 0          Aruba
# 1        Andorra
# 2    Afghanistan
# Name: Country Name, dtype: object

# %% [markdown]
# ### exercise: select the last 5 rows of the last 2 columns

# %%
df_co2.iloc[-5:,-2:]
# Out:
#      2015  Unnamed: 60
# 243   NaN          NaN
# 244   NaN          NaN
# 245   NaN          NaN
# 246   NaN          NaN
# 247   NaN          NaN

# %%
df_co2.columns
# Out:
# Index([  u'Country Name',   u'Country Code', u'Indicator Name',
#        u'Indicator Code',           u'1960',           u'1961',
#                  u'1962',           u'1963',           u'1964',
#                  u'1965',           u'1966',           u'1967',
#                  u'1968',           u'1969',           u'1970',
#                  u'1971',           u'1972',           u'1973',
#                  u'1974',           u'1975',           u'1976',
#                  u'1977',           u'1978',           u'1979',
#                  u'1980',           u'1981',           u'1982',
#                  u'1983',           u'1984',           u'1985',
#                  u'1986',           u'1987',           u'1988',
#                  u'1989',           u'1990',           u'1991',
#                  u'1992',           u'1993',           u'1994',
#                  u'1995',           u'1996',           u'1997',
#                  u'1998',           u'1999',           u'2000',
#                  u'2001',           u'2002',           u'2003',
#                  u'2004',           u'2005',           u'2006',
#                  u'2007',           u'2008',           u'2009',
#                  u'2010',           u'2011',           u'2012',
#                  u'2013',           u'2014',           u'2015',
#           u'Unnamed: 60'],
#       dtype='object')

# %% [markdown]
# ### Boolean Indexing

# %%
20 > 10
# Out:
# True

# %%
'a' == 'b'
# Out:
# False

# %%
20 > 10 and 'a' == 'b'
# Out:
# False

# %%
20 > 10 or 'a' == 'b'
# Out:
# True

# %%
#selecting rows following a criterium
df_co2['Country Name'] == 'Canada'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 218    False
# 219    False
# 220    False
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# Name: Country Name, dtype: bool

# %%
df_co2[df_co2['Country Name'] == 'Canada']
# Out:
#    Country Name Country Code                          Indicator Name  \
# 33       Canada          CAN  CO2 emissions (metric tons per capita)
#
#     Indicator Code       1960       1961       1962       1963      1964  \
# 33  EN.ATM.CO2E.PC  10.770847  10.627898  11.130627  11.132102  12.30537
#
#          1965     ...          2007       2008       2009       2010  \
# 33  12.814001     ...       17.0519  16.366165  15.089098  14.589054
#
#          2011  2012  2013  2014  2015  Unnamed: 60
# 33  14.135813   NaN   NaN   NaN   NaN          NaN
#
# [1 rows x 61 columns]

# %%
df_co2[(df_co2['1960'] > 10) & 
       (df_co2['1960'] < 12)]
# Out:
#        Country Name Country Code                          Indicator Name  \
# 33           Canada          CAN  CO2 emissions (metric tons per capita)
# 77   United Kingdom          GBR  CO2 emissions (metric tons per capita)
# 162   New Caledonia          NCL  CO2 emissions (metric tons per capita)
#
#      Indicator Code       1960       1961       1962       1963       1964  \
# 33   EN.ATM.CO2E.PC  10.770847  10.627898  11.130627  11.132102  12.305370
# 77   EN.ATM.CO2E.PC  11.150759  11.154139  11.142928  11.254853  11.265839
# 162  EN.ATM.CO2E.PC  10.908165  10.928744   6.771199   7.231307  12.486947
#
#           1965     ...            2007       2008       2009       2010  \
# 33   12.814001     ...       17.051900  16.366165  15.089098  14.589054
# 77   11.456160     ...        8.615489   8.437773   7.599000   7.841653
# 162  13.614497     ...       12.325560  13.531310  11.570830  15.680092
#
#           2011  2012  2013  2014  2015  Unnamed: 60
# 33   14.135813   NaN   NaN   NaN   NaN          NaN
# 77    7.085732   NaN   NaN   NaN   NaN          NaN
# 162  15.173295   NaN   NaN   NaN   NaN          NaN
#
# [3 rows x 61 columns]

# %%
df_co2[(df_co2['1960'] > 15) | 
       (df_co2['1960'] < 0.1)]
# Out:
#                                      Country Name Country Code  \
# 2                                     Afghanistan          AFG
# 16                                          Benin          BEN
# 17                                   Burkina Faso          BFA
# 32                       Central African Republic          CAF
# 40                                       Cameroon          CMR
# 43                                        Comoros          COM
# 68                                       Ethiopia          ETH
# 81                                    Gambia, The          GMB
# 82                                  Guinea-Bissau          GNB
# 83                              Equatorial Guinea          GNQ
# 95                                          Haiti          HTI
# 113                                      Cambodia          KHM
# 118                                        Kuwait          KWT
# 120                                       Lao PDR          LAO
# 126  Least developed countries: UN classification          LDC
# 134                                    Luxembourg          LUX
# 141                                    Madagascar          MDG
# 148                                          Mali          MLI
# 156                                    Mauritania          MRT
# 160                                 North America          NAC
# 163                                         Niger          NER
# 164                                       Nigeria          NGA
# 169                                         Nepal          NPL
# 180                              Papua New Guinea          PNG
# 191                                        Rwanda          RWA
# 197                               Solomon Islands          SLB
# 201                                       Somalia          SOM
# 212                                     Swaziland          SWZ
# 217                                          Chad          TCD
# 218                                          Togo          TGO
# 228                                      Tanzania          TZA
# 229                                        Uganda          UGA
# 233                                 United States          USA
#
#                              Indicator Name  Indicator Code       1960  \
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0
# 134   NaN          NaN
# 141   NaN          NaN
# 148   NaN          NaN
# 156   NaN          NaN
# 160   NaN          NaN
# 163   NaN          NaN
# 164   NaN          NaN
# 169   NaN          NaN
# 180   NaN          NaN
# 191   NaN          NaN
# 197   NaN          NaN
# 201   NaN          NaN
# 212   NaN          NaN
# 217   NaN          NaN
# 218   NaN          NaN
# 228   NaN          NaN
# 229   NaN          NaN
# 233   NaN          NaN
#
# [33 rows x 61 columns]

# %% [markdown]
# ### how do you select the rows from Canada and Brazil?

# %%
df_co2[(df_co2['Country Name'] == 'Canada') | 
       (df_co2['Country Name'] == 'Brazil')]
# Out:
#    Country Name Country Code                          Indicator Name  \
# 27       Brazil          BRA  CO2 emissions (metric tons per capita)
# 33       Canada          CAN  CO2 emissions (metric tons per capita)
#
#     Indicator Code       1960       1961       1962       1963       1964  \
# 27  EN.ATM.CO2E.PC   0.647068   0.658625   0.697281   0.700749   0.694001
# 33  EN.ATM.CO2E.PC  10.770847  10.627898  11.130627  11.132102  12.305370
#
#          1965     ...            2007       2008       2009       2010  \
# 27   0.670372     ...        1.884034   1.990429   1.866522   2.113415
# 33  12.814001     ...       17.051900  16.366165  15.089098  14.589054
#
#          2011  2012  2013  2014  2015  Unnamed: 60
# 27   2.191394   NaN   NaN   NaN   NaN          NaN
# 33  14.135813   NaN   NaN   NaN   NaN          NaN
#
# [2 rows x 61 columns]

# %%
#check number of countries
df_co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 61 columns):
# Country Name      248 non-null object
# Country Code      248 non-null object
# Indicator Name    248 non-null object
# Indicator Code    248 non-null object
# 1960              178 non-null float64
# 1961              179 non-null float64
# 1962              180 non-null float64
# 1963              181 non-null float64
# 1964              186 non-null float64
# 1965              186 non-null float64
# 1966              186 non-null float64
# 1967              186 non-null float64
# 1968              185 non-null float64
# 1969              186 non-null float64
# 1970              188 non-null float64
# 1971              189 non-null float64
# 1972              192 non-null float64
# 1973              192 non-null float64
# 1974              192 non-null float64
# 1975              192 non-null float64
# 1976              192 non-null float64
# 1977              192 non-null float64
# 1978              192 non-null float64
# 1979              192 non-null float64
# 1980              192 non-null float64
# 1981              192 non-null float64
# 1982              192 non-null float64
# 1983              192 non-null float64
# 1984              192 non-null float64
# 1985              192 non-null float64
# 1986              193 non-null float64
# 1987              193 non-null float64
# 1988              193 non-null float64
# 1989              193 non-null float64
# 1990              195 non-null float64
# 1991              196 non-null float64
# 1992              219 non-null float64
# 1993              219 non-null float64
# 1994              220 non-null float64
# 1995              223 non-null float64
# 1996              222 non-null float64
# 1997              224 non-null float64
# 1998              226 non-null float64
# 1999              226 non-null float64
# 2000              227 non-null float64
# 2001              227 non-null float64
# 2002              228 non-null float64
# 2003              228 non-null float64
# 2004              228 non-null float64
# 2005              230 non-null float64
# 2006              231 non-null float64
# 2007              232 non-null float64
# 2008              232 non-null float64
# 2009              232 non-null float64
# 2010              232 non-null float64
# 2011              232 non-null float64
# 2012              0 non-null float64
# 2013              0 non-null float64
# 2014              0 non-null float64
# 2015              0 non-null float64
# Unnamed: 60       0 non-null float64
# dtypes: float64(57), object(4)
# memory usage: 118.3+ KB

# %%
df_co2['Country Name'].unique()
# Out:
# array([u'Aruba', u'Andorra', u'Afghanistan', u'Angola', u'Albania',
#        u'Arab World', u'United Arab Emirates', u'Argentina', u'Armenia',
#        u'American Samoa', u'Antigua and Barbuda', u'Australia', u'Austria',
#        u'Azerbaijan', u'Burundi', u'Belgium', u'Benin', u'Burkina Faso',
#        u'Bangladesh', u'Bulgaria', u'Bahrain', u'Bahamas, The',
#        u'Bosnia and Herzegovina', u'Belarus', u'Belize', u'Bermuda',
#        u'Bolivia', u'Brazil', u'Barbados', u'Brunei Darussalam', u'Bhutan',
#        u'Botswana', u'Central African Republic', u'Canada',
#        u'Central Europe and the Baltics', u'Switzerland',
#        u'Channel Islands', u'Chile', u'China', u"Cote d'Ivoire",
#        u'Cameroon', u'Congo, Rep.', u'Colombia', u'Comoros', u'Cabo Verde',
#        u'Costa Rica', u'Caribbean small states', u'Cuba', u'Curacao',
#        u'Cayman Islands', u'Cyprus', u'Czech Republic', u'Germany',
#        u'Djibouti', u'Dominica', u'Denmark', u'Dominican Republic',
#        u'Algeria', u'East Asia & Pacific (developing only)',
#        u'East Asia & Pacific (all income levels)',
#        u'Europe & Central Asia (developing only)',
#        u'Europe & Central Asia (all income levels)', u'Ecuador',
#        u'Egypt, Arab Rep.', u'Euro area', u'Eritrea', u'Spain', u'Estonia',
#        u'Ethiopia', u'European Union',
#        u'Fragile and conflict affected situations', u'Finland', u'Fiji',
#        u'France', u'Faeroe Islands', u'Micronesia, Fed. Sts.', u'Gabon',
#        u'United Kingdom', u'Georgia', u'Ghana', u'Guinea', u'Gambia, The',
#        u'Guinea-Bissau', u'Equatorial Guinea', u'Greece', u'Grenada',
#        u'Greenland', u'Guatemala', u'Guam', u'Guyana', u'High income',
#        u'Hong Kong SAR, China', u'Honduras',
#        u'Heavily indebted poor countries (HIPC)', u'Croatia', u'Haiti',
#        u'Hungary', u'Indonesia', u'Isle of Man', u'India',
#        u'Not classified', u'Ireland', u'Iran, Islamic Rep.', u'Iraq',
#        u'Iceland', u'Israel', u'Italy', u'Jamaica', u'Jordan', u'Japan',
#        u'Kazakhstan', u'Kenya', u'Kyrgyz Republic', u'Cambodia',
#        u'Kiribati', u'St. Kitts and Nevis', u'Korea, Rep.', u'Kosovo',
#        u'Kuwait', u'Latin America & Caribbean (developing only)',
#        u'Lao PDR', u'Lebanon', u'Liberia', u'Libya', u'St. Lucia',
#        u'Latin America & Caribbean (all income levels)',
#        u'Least developed countries: UN classification', u'Low income',
#        u'Liechtenstein', u'Sri Lanka', u'Lower middle income',
#        u'Low & middle income', u'Lesotho', u'Lithuania', u'Luxembourg',
#        u'Latvia', u'Macao SAR, China', u'St. Martin (French part)',
#        u'Morocco', u'Monaco', u'Moldova', u'Madagascar', u'Maldives',
#        u'Middle East & North Africa (all income levels)', u'Mexico',
#        u'Marshall Islands', u'Middle income', u'Macedonia, FYR', u'Mali',
#        u'Malta', u'Myanmar',
#        u'Middle East & North Africa (developing only)', u'Montenegro',
#        u'Mongolia', u'Northern Mariana Islands', u'Mozambique',
#        u'Mauritania', u'Mauritius', u'Malawi', u'Malaysia',
#        u'North America', u'Namibia', u'New Caledonia', u'Niger',
#        u'Nigeria', u'Nicaragua', u'Netherlands', u'High income: nonOECD',
#        u'Norway', u'Nepal', u'New Zealand', u'High income: OECD',
#        u'OECD members', u'Oman', u'Other small states', u'Pakistan',
#        u'Panama', u'Peru', u'Philippines', u'Palau', u'Papua New Guinea',
#        u'Poland', u'Puerto Rico', u'Korea, Dem. Rep.', u'Portugal',
#        u'Paraguay', u'Pacific island small states', u'French Polynesia',
#        u'Qatar', u'Romania', u'Russian Federation', u'Rwanda',
#        u'South Asia', u'Saudi Arabia', u'Sudan', u'Senegal', u'Singapore',
#        u'Solomon Islands', u'Sierra Leone', u'El Salvador', u'San Marino',
#        u'Somalia', u'Serbia', u'Sub-Saharan Africa (developing only)',
#        u'South Sudan', u'Sub-Saharan Africa (all income levels)',
#        u'Small states', u'Sao Tome and Principe', u'Suriname',
#        u'Slovak Republic', u'Slovenia', u'Sweden', u'Swaziland',
#        u'Sint Maarten (Dutch part)', u'Seychelles',
#        u'Syrian Arab Republic', u'Turks and Caicos Islands', u'Chad',
#        u'Togo', u'Thailand', u'Tajikistan', u'Turkmenistan',
#        u'Timor-Leste', u'Tonga', u'Trinidad and Tobago', u'Tunisia',
#        u'Turkey', u'Tuvalu', u'Tanzania', u'Uganda', u'Ukraine',
#        u'Upper middle income', u'Uruguay', u'United States', u'Uzbekistan',
#        u'St. Vincent and the Grenadines', u'Venezuela, RB',
#        u'Virgin Islands (U.S.)', u'Vietnam', u'Vanuatu',
#        u'West Bank and Gaza', u'World', u'Samoa', u'Yemen, Rep.',
#        u'South Africa', u'Congo, Dem. Rep.', u'Zambia', u'Zimbabwe'], dtype=object)

# %% [markdown]
# ### Remove empty columns

# %%
df_co2.columns[-5:]
# Out:
# Index([u'2012', u'2013', u'2014', u'2015', u'Unnamed: 60'], dtype='object')

# %%
df_co2.columns
# Out:
# Index([  u'Country Name',   u'Country Code', u'Indicator Name',
#        u'Indicator Code',           u'1960',           u'1961',
#                  u'1962',           u'1963',           u'1964',
#                  u'1965',           u'1966',           u'1967',
#                  u'1968',           u'1969',           u'1970',
#                  u'1971',           u'1972',           u'1973',
#                  u'1974',           u'1975',           u'1976',
#                  u'1977',           u'1978',           u'1979',
#                  u'1980',           u'1981',           u'1982',
#                  u'1983',           u'1984',           u'1985',
#                  u'1986',           u'1987',           u'1988',
#                  u'1989',           u'1990',           u'1991',
#                  u'1992',           u'1993',           u'1994',
#                  u'1995',           u'1996',           u'1997',
#                  u'1998',           u'1999',           u'2000',
#                  u'2001',           u'2002',           u'2003',
#                  u'2004',           u'2005',           u'2006',
#                  u'2007',           u'2008',           u'2009',
#                  u'2010',           u'2011',           u'2012',
#                  u'2013',           u'2014',           u'2015',
#           u'Unnamed: 60'],
#       dtype='object')

# %%
df_co2.shape
# Out:
# (248, 61)

# %%
df_co2.drop(df_co2.columns[-5:], axis = 1)
# Out:
#                        Country Name Country Code  \
# 0                             Aruba          ABW
# 1                           Andorra          AND
# 2                       Afghanistan          AFG
# 3                            Angola          AGO
# 4                           Albania          ALB
# 5                        Arab World          ARB
# 6              United Arab Emirates          ARE
# 7                         Argentina          ARG
# 8                           Armenia          ARM
# 9                    American Samoa          ASM
# 10              Antigua and Barbuda          ATG
# 11                        Australia          AUS
# 12                          Austria          AUT
# 13                       Azerbaijan          AZE
# 14                          Burundi          BDI
# 15                          Belgium          BEL
# 16                            Benin          BEN
# 17                     Burkina Faso          BFA
# 18                       Bangladesh          BGD
# 19                         Bulgaria          BGR
# 20                          Bahrain          BHR
# 21                     Bahamas, The          BHS
# 22           Bosnia and Herzegovina          BIH
# 23                          Belarus          BLR
# 24                           Belize          BLZ
# 25                          Bermuda          BMU
# 26                          Bolivia          BOL
# 27                           Brazil          BRA
# 28                         Barbados          BRB
# 29                Brunei Darussalam          BRN
# ..                              ...          ...
# 218                            Togo          TGO
# 219                        Thailand          THA
# 220                      Tajikistan          TJK
# 221                    Turkmenistan          TKM
# 222                     Timor-Leste          TLS
# 223                           Tonga          TON
# 224             Trinidad and Tobago          TTO
# 225                         Tunisia          TUN
# 226                          Turkey          TUR
# 227                          Tuvalu          TUV
# 228                        Tanzania          TZA
# 229                          Uganda          UGA
# 230                         Ukraine          UKR
# 231             Upper middle income          UMC
# 232                         Uruguay          URY
# 233                   United States          USA
# 234                      Uzbekistan          UZB
# 235  St. Vincent and the Grenadines          VCT
# 236                   Venezuela, RB          VEN
# 237           Virgin Islands (U.S.)          VIR
# 238                         Vietnam          VNM
# 239                         Vanuatu          VUT
# 240              West Bank and Gaza          PSE
# 241                           World          WLD
# 242                           Samoa          WSM
# 243                     Yemen, Rep.          YEM
# 244                    South Africa          ZAF
# 245                Congo, Dem. Rep.          COD
# 246                          Zambia          ZMB
# 247                        Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.046068
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.104357
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.643964
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.118786
# 7    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.367473
# 8    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 9    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 10   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.670617
# 11   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   8.582937
# 12   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.373319
# 13   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 14   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 15   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   9.941594
# 16   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.066354
# 17   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.009112
# 18   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.833901
# 20   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.542864
# 21   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.749831
# 22   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 23   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 24   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.477951
# 25   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.551374
# 26   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.272038
# 27   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.647068
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.746313
# 29   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.078179
# ..                                      ...             ...        ...
# 218  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.041762
# 219  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135586
# 220  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 221  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 222  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 223  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.178588
# 224  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.042576
# 225  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.409211
# 226  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.610473
# 227  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 228  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.082261
# 229  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.062123
# 230  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 231  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.288256
# 232  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.701583
# 233  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  15.999779
# 234  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 235  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135902
# 236  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   7.005107
# 237  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 238  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.215631
# 239  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 240  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 241  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.096144
# 242  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135009
# 243  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.703403
# 244  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   5.629718
# 245  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.152228
# 246  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 247  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
#
#           1961       1962       1963       1964       1965    ...      \
# 0          NaN        NaN        NaN        NaN        NaN    ...
# 1          NaN        NaN        NaN        NaN        NaN    ...
# 2     0.053615   0.073781   0.074251   0.086317   0.101499    ...
# 3     0.084718   0.216025   0.206877   0.216174   0.206089    ...
# 4     1.374186   1.439956   1.181681   1.111742   1.166099    ...
# 5     0.685501   0.761148   0.875124   0.999248   1.166075    ...
# 6     0.108937   0.163355   0.175712   0.132651   0.146370    ...
# 7     2.442616   2.522392   2.316356   2.538380   2.641714    ...
# 8          NaN        NaN        NaN        NaN        NaN    ...
# 9          NaN        NaN        NaN        NaN        NaN    ...
# 10    0.860441   1.823374   1.470175   1.567094   2.520359    ...
# 11    8.641569   8.835688   9.226440   9.759073  10.622321    ...
# 12    4.496362   4.755362   5.155194   5.391004   5.252197    ...
# 13         NaN        NaN        NaN        NaN        NaN    ...
# 14         NaN   0.015203   0.016155   0.015827   0.011910    ...
# 15   10.103872  10.641190  11.386929  11.053655  11.141656    ...
# 16    0.052046   0.054202   0.047580   0.055295   0.057115    ...
# 17    0.018730   0.017003   0.017504   0.021575   0.019841    ...
# 18         NaN        NaN        NaN        NaN        NaN    ...
# 19    3.269920   3.835892   4.259781   5.262988   5.645652    ...
# 20   10.547396   9.193609   6.714156   8.747480   6.557022    ...
# 21    4.746699   5.996432   5.558199   8.118597   9.399946    ...
# 22         NaN        NaN        NaN        NaN        NaN    ...
# 23         NaN        NaN        NaN        NaN        NaN    ...
# 24    0.387219   0.715409   0.622357   0.818289   0.794763    ...
# 25    3.868484   3.383712   3.151929   4.124438   3.586487    ...
# 26    0.276621   0.286626   0.310159   0.371216   0.371151    ...
# 27    0.658625   0.697281   0.700749   0.694001   0.670372    ...
# 28    0.838899   1.119411   0.816330   0.766085   0.872454    ...
# 29    3.552009   4.133422   3.798174   3.482289   3.254787    ...
# ..         ...        ...        ...        ...        ...    ...
# 218   0.057386   0.054570   0.065171   0.079426   0.077262    ...
# 219   0.146944   0.173130   0.185877   0.242240   0.234151    ...
# 220        NaN        NaN        NaN        NaN        NaN    ...
# 221        NaN        NaN        NaN        NaN        NaN    ...
# 222        NaN        NaN        NaN        NaN        NaN    ...
# 223   0.172592   0.166040   0.159435   0.153309   0.147936    ...
# 224   5.318141   8.225570   1.466683   4.201774   5.694904    ...
# 225   0.413220   0.412987   0.438885   0.608626   0.532230    ...
# 226   0.615079   0.748241   0.765934   0.869390   0.883506    ...
# 227        NaN        NaN        NaN        NaN        NaN    ...
# 228   0.067872   0.071734   0.072968   0.091197   0.099494    ...
# 229   0.058093   0.059258   0.057791   0.063435   0.078242    ...
# 230        NaN        NaN        NaN        NaN        NaN    ...
# 231   1.057435   0.957318   0.955719   0.982914   1.036033    ...
# 232   1.602723   1.540657   1.639285   1.710101   2.049519    ...
# 233  15.681256  16.013937  16.482762  16.968119  17.451725    ...
# 234        NaN        NaN        NaN        NaN        NaN    ...
# 235   0.133923   0.132214   0.174273   0.215513   0.170614    ...
# 236   6.136886   6.155057   6.155748   5.973226   6.187252    ...
# 237        NaN        NaN        NaN        NaN        NaN    ...
# 238   0.225435   0.258760   0.247579   0.314058   0.343354    ...
# ..         ...        ...        ...        ...
# 218   0.285948   0.270614   0.269107   0.319444
# 219   3.984060   4.198512   4.470426   4.534492
# 220   0.409462   0.382775   0.373873   0.358948
# 221  11.557572  10.110661  11.358111  12.183667
# 222   0.185017   0.174891   0.171932   0.163648
# 223   1.176967   1.276514   1.128883   0.983562
# 224  35.455298  36.569448  38.337841  37.140054
# 225   2.403508   2.374157   2.535619   2.402456
# 226   4.055397   3.898959   4.121155   4.383105
# 227        NaN        NaN        NaN        NaN
# 228   0.147982   0.139973   0.150059   0.154935
# 229   0.101919   0.105320   0.108297   0.110887
# 230   6.724046   5.647014   6.638152   6.262352
# 231   4.838153   5.074765   5.359187   5.710564
# 232   2.471054   2.401221   1.912605   2.296201
# 233  18.489234  17.192379  17.484792  17.020216
# 234   4.434466   3.912053   3.693268   3.914921
# 235   2.116255   2.114512   2.146877   2.179923
# 236   6.604892   6.525293   6.811756   6.416334
# 237        NaN        NaN        NaN        NaN
# 238   1.497496   1.636371   1.761695   1.971889
# 239   0.406839   0.508463   0.496591   0.591266
# 240   0.570947   0.564578   0.534015   0.572407
# 241   4.741797   4.663097   4.840412   4.944649
# 242   1.039490   1.072106   1.103871   1.252110
# 243   0.989905   1.026251   1.090060   0.919968
# 244   9.506481   9.545495   8.957154   9.257216
# 245   0.048411   0.045604   0.049328   0.050303
# 246   0.164692   0.184058   0.192079   0.212450
# 247   0.569255   0.600521   0.646073   0.691698
#
# [248 rows x 56 columns]

# %%
df_co2.drop(df_co2.columns[-5:], axis = 1).shape
# Out:
# (248, 56)

# %%
df_co2 = df_co2.drop(df_co2.columns[-5:], axis = 1)

# %% [markdown]
# ### ex: remove column "Indicator Code"

# %%
df_co2 = df_co2.drop('Indicator Code', axis = 1)

# %% [markdown]
# ### Check dataframe again

# %%
df_co2.head()
# Out:
#   Country Name Country Code                          Indicator Name      1960  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)       NaN
# 1      Andorra          AND  CO2 emissions (metric tons per capita)       NaN
# 2  Afghanistan          AFG  CO2 emissions (metric tons per capita)  0.046068
# 3       Angola          AGO  CO2 emissions (metric tons per capita)  0.104357
# 4      Albania          ALB  CO2 emissions (metric tons per capita)  1.258195
#
#        1961      1962      1963      1964      1965      1966    ...      \
# 0       NaN       NaN       NaN       NaN       NaN       NaN    ...
# 1       NaN       NaN       NaN       NaN       NaN       NaN    ...
# 2  0.053615  0.073781  0.074251  0.086317  0.101499  0.107674    ...
# 3  0.084718  0.216025  0.206877  0.216174  0.206089  0.265164    ...
# 4  1.374186  1.439956  1.181681  1.111742  1.166099  1.333055    ...
#
#         2002       2003       2004       2005       2006       2007  \
# 0  24.975515  24.909066  24.510543  24.964531  24.766706  25.613715
# 1   7.484095   7.159140   7.208829   7.088128   6.553477   6.350868
# 2   0.041641   0.046108   0.040727   0.054855   0.065816   0.088141
# 3   0.786223   0.543084   1.086605   1.069417   1.200877   1.311096
# 4   1.229541   1.412697   1.376213   1.412498   1.291548   1.507536
#
#         2008       2009       2010       2011
# 0  24.750133  24.876706  24.182702  23.922412
# 1   6.296125   6.049173   6.124770   5.968685
# 2   0.158962   0.249074   0.302936   0.425262
# 3   1.369425   1.430873   1.401654   1.354008
# 4   1.580113   1.533178   1.515632   1.607038
#
# [5 rows x 55 columns]

# %% [markdown]
# ## Remove rows without any data

# %%
df_co2.mean(axis = 1)
# Out:
# 0      21.766264
# 1       6.926680
# 2       0.139113
# 3       0.610377
# 4       1.657433
# 5       2.874468
# 6      31.844877
# 7       3.563240
# 8       1.230824
# 9            NaN
# 10      5.106829
# 11     14.364944
# 12      7.200894
# 13      4.257653
# 14      0.032397
# 15     11.372211
# 16      0.184605
# 17      0.060372
# 18      0.174804
# 19      7.181894
# 20     19.867874
# 21     12.989496
# 22      3.336662
# 23      6.194563
# 24      1.384584
# 25      7.125285
# 26      0.906155
# 27      1.406963
# 28      3.143447
# 29     21.497854
#          ...
# 218     0.197678
# 219     1.726478
# 220     0.459464
# 221     8.943359
# 222     0.177336
# 223     0.630603
# 224    15.802071
# 225     1.482407
# 226     2.310214
# 227          NaN
# 228     0.114896
# 229     0.073733
# 230     7.434661
# 231     2.542205
# 232     1.742226
# 233    19.303472
# 234     4.623481
# 235     0.870765
# 236     5.959301
# 237          NaN
# 238     0.598837
# 239     0.517542
# 240     0.471235
# 241     4.088235
# 242     0.612593
# 243     0.737396
# 244     8.230187
# 245     0.104890
# 246     0.495172
# 247     1.228627
# dtype: float64

# %% [markdown]
# ### Missing values

# %%
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
type(np.nan)
# Out:
# float

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
df_co2.mean(axis = 1).isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 218    False
# 219    False
# 220    False
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# 227     True
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237     True
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# 247    False
# dtype: bool

# %%
df_co2[df_co2.mean(axis = 1).isnull()]
# Out:
#                   Country Name Country Code  \
# 9               American Samoa          ASM
# 36             Channel Islands          CHI
# 48                     Curacao          CUW
# 88                        Guam          GUM
# 98                 Isle of Man          IMN
# 100             Not classified          INX
# 117                     Kosovo          KSV
# 137   St. Martin (French part)          MAF
# 139                     Monaco          MCO
# 154   Northern Mariana Islands          MNP
# 182                Puerto Rico          PRI
# 200                 San Marino          SMR
# 204                South Sudan          SSD
# 213  Sint Maarten (Dutch part)          SXM
# 227                     Tuvalu          TUV
# 237      Virgin Islands (U.S.)          VIR
#
#                              Indicator Name  1960  1961  1962  1963  1964  \
# 9    CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 36   CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 48   CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 88   CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 98   CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 100  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 117  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 137  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 139  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 154  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 182  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 200  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 204  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 213  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 227  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
# 237  CO2 emissions (metric tons per capita)   NaN   NaN   NaN   NaN   NaN
#
#      1965  1966  ...   2002  2003  2004  2005  2006  2007  2008  2009  2010  \
# 9     NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 36    NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 48    NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 88    NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 98    NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 100   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 117   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 137   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 139   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 154   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 182   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 200   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 204   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 213   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 227   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 237   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2011
# 9     NaN
# 36    NaN
# 48    NaN
# 88    NaN
# 98    NaN
# 100   NaN
# 117   NaN
# 137   NaN
# 139   NaN
# 154   NaN
# 182   NaN
# 200   NaN
# 204   NaN
# 213   NaN
# 227   NaN
# 237   NaN
#
# [16 rows x 55 columns]

# %%
df_co2[df_co2.mean(axis = 1).isnull()].shape
# Out:
# (16, 55)

# %%
removed_rows_nan = df_co2[df_co2.mean(axis = 1).isnull()]

# %%
df_co2[df_co2.mean(axis = 1).notnull()]
# Out:
#                        Country Name Country Code  \
# 0                             Aruba          ABW
# 1                           Andorra          AND
# 2                       Afghanistan          AFG
# 3                            Angola          AGO
# 4                           Albania          ALB
# 5                        Arab World          ARB
# 6              United Arab Emirates          ARE
# 7                         Argentina          ARG
# 8                           Armenia          ARM
# 10              Antigua and Barbuda          ATG
# 11                        Australia          AUS
# 12                          Austria          AUT
# 13                       Azerbaijan          AZE
# 14                          Burundi          BDI
# 15                          Belgium          BEL
# 16                            Benin          BEN
# 17                     Burkina Faso          BFA
# 18                       Bangladesh          BGD
# 19                         Bulgaria          BGR
# 20                          Bahrain          BHR
# 21                     Bahamas, The          BHS
# 22           Bosnia and Herzegovina          BIH
# 23                          Belarus          BLR
# 24                           Belize          BLZ
# 25                          Bermuda          BMU
# 26                          Bolivia          BOL
# 27                           Brazil          BRA
# 28                         Barbados          BRB
# 29                Brunei Darussalam          BRN
# 30                           Bhutan          BTN
# ..                              ...          ...
# 216        Turks and Caicos Islands          TCA
# 217                            Chad          TCD
# 218                            Togo          TGO
# 219                        Thailand          THA
# 220                      Tajikistan          TJK
# 221                    Turkmenistan          TKM
# 222                     Timor-Leste          TLS
# 223                           Tonga          TON
# 224             Trinidad and Tobago          TTO
# 225                         Tunisia          TUN
# 226                          Turkey          TUR
# 228                        Tanzania          TZA
# 229                          Uganda          UGA
# 230                         Ukraine          UKR
# 231             Upper middle income          UMC
# 232                         Uruguay          URY
# 233                   United States          USA
# 234                      Uzbekistan          UZB
# 235  St. Vincent and the Grenadines          VCT
# 236                   Venezuela, RB          VEN
# 238                         Vietnam          VNM
# 239                         Vanuatu          VUT
# 240              West Bank and Gaza          PSE
# 241                           World          WLD
# 242                           Samoa          WSM
# 243                     Yemen, Rep.          YEM
# 244                    South Africa          ZAF
# 245                Congo, Dem. Rep.          COD
# 246                          Zambia          ZMB
# 247                        Zimbabwe          ZWE
#
#                              Indicator Name       1960       1961       1962  \
# 0    CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 1    CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 2    CO2 emissions (metric tons per capita)   0.046068   0.053615   0.073781
# 3    CO2 emissions (metric tons per capita)   0.104357   0.084718   0.216025
# 4    CO2 emissions (metric tons per capita)   1.258195   1.374186   1.439956
# 5    CO2 emissions (metric tons per capita)   0.643964   0.685501   0.761148
# 6    CO2 emissions (metric tons per capita)   0.118786   0.108937   0.163355
# 7    CO2 emissions (metric tons per capita)   2.367473   2.442616   2.522392
# 8    CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 10   CO2 emissions (metric tons per capita)   0.670617   0.860441   1.823374
# 11   CO2 emissions (metric tons per capita)   8.582937   8.641569   8.835688
# 12   CO2 emissions (metric tons per capita)   4.373319   4.496362   4.755362
# 13   CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 14   CO2 emissions (metric tons per capita)        NaN        NaN   0.015203
# 15   CO2 emissions (metric tons per capita)   9.941594  10.103872  10.641190
# 16   CO2 emissions (metric tons per capita)   0.066354   0.052046   0.054202
# 17   CO2 emissions (metric tons per capita)   0.009112   0.018730   0.017003
# 18   CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 19   CO2 emissions (metric tons per capita)   2.833901   3.269920   3.835892
# 20   CO2 emissions (metric tons per capita)   3.542864  10.547396   9.193609
# 21   CO2 emissions (metric tons per capita)   3.749831   4.746699   5.996432
# 22   CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 23   CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 24   CO2 emissions (metric tons per capita)   0.477951   0.387219   0.715409
# 25   CO2 emissions (metric tons per capita)   3.551374   3.868484   3.383712
# 26   CO2 emissions (metric tons per capita)   0.272038   0.276621   0.286626
# 27   CO2 emissions (metric tons per capita)   0.647068   0.658625   0.697281
# 28   CO2 emissions (metric tons per capita)   0.746313   0.838899   1.119411
# 29   CO2 emissions (metric tons per capita)   4.078179   3.552009   4.133422
# 30   CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# ..                                      ...        ...        ...        ...
# 216  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 217  CO2 emissions (metric tons per capita)   0.018319   0.016769   0.027012
# 218  CO2 emissions (metric tons per capita)   0.041762   0.057386   0.054570
# 219  CO2 emissions (metric tons per capita)   0.135586   0.146944   0.173130
# 220  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 221  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 222  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 223  CO2 emissions (metric tons per capita)   0.178588   0.172592   0.166040
# 224  CO2 emissions (metric tons per capita)   3.042576   5.318141   8.225570
# 225  CO2 emissions (metric tons per capita)   0.409211   0.413220   0.412987
# 226  CO2 emissions (metric tons per capita)   0.610473   0.615079   0.748241
# 228  CO2 emissions (metric tons per capita)   0.082261   0.067872   0.071734
# 229  CO2 emissions (metric tons per capita)   0.062123   0.058093   0.059258
# 230  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 231  CO2 emissions (metric tons per capita)   1.288256   1.057435   0.957318
# 232  CO2 emissions (metric tons per capita)   1.701583   1.602723   1.540657
# 233  CO2 emissions (metric tons per capita)  15.999779  15.681256  16.013937
# 234  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 235  CO2 emissions (metric tons per capita)   0.135902   0.133923   0.132214
# 236  CO2 emissions (metric tons per capita)   7.005107   6.136886   6.155057
# 238  CO2 emissions (metric tons per capita)   0.215631   0.225435   0.258760
# 239  CO2 emissions (metric tons per capita)        NaN        NaN   0.594888
# 240  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 241  CO2 emissions (metric tons per capita)   3.096144   3.067062   3.138020
# 242  CO2 emissions (metric tons per capita)   0.135009   0.163529   0.158352
# 243  CO2 emissions (metric tons per capita)   0.703403   0.507631   0.728004
# 244  CO2 emissions (metric tons per capita)   5.629718   5.694383   5.729712
# 245  CO2 emissions (metric tons per capita)   0.152228   0.150782   0.135559
# 246  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
# 247  CO2 emissions (metric tons per capita)        NaN        NaN        NaN
#
#           1963       1964       1965       1966    ...           2002  \
# 0          NaN        NaN        NaN        NaN    ...      24.975515
# 1          NaN        NaN        NaN        NaN    ...       7.484095
# 2     0.074251   0.086317   0.101499   0.107674    ...       0.041641
# 3     0.206877   0.216174   0.206089   0.265164    ...       0.786223
# 4     1.181681   1.111742   1.166099   1.333055    ...       1.229541
# 5     0.875124   0.999248   1.166075   1.273618    ...       3.579922
# 6     0.175712   0.132651   0.146370   0.159359    ...      24.956551
# 7     2.316356   2.538380   2.641714   2.792654    ...       3.253313
# 8          NaN        NaN        NaN        NaN    ...       0.998806
# 10    1.470175   1.567094   2.520359   5.727992    ...       4.536211
# 11    9.226440   9.759073  10.622321  10.328092    ...      17.372318
# 12    5.155194   5.391004   5.252197   5.361725    ...       8.287319
# 13         NaN        NaN        NaN        NaN    ...       3.623944
# 14    0.016155   0.015827   0.011910   0.015115    ...       0.029705
# 15   11.386929  11.053655  11.141656  11.042019    ...      10.364911
# 16    0.047580   0.055295   0.057115   0.042395    ...       0.280413
# 17    0.017504   0.021575   0.019841   0.019534    ...       0.081748
# 18         NaN        NaN        NaN        NaN    ...       0.247430
# 19    4.259781   5.262988   5.645652   5.905437    ...       5.672607
# 20    6.714156   8.747480   6.557022   3.384358    ...      21.642107
# 21    5.558199   8.118597   9.399946   7.466085    ...       5.100139
# 22         NaN        NaN        NaN        NaN    ...       3.755251
# 23         NaN        NaN        NaN        NaN    ...       5.310738
# 24    0.622357   0.818289   0.794763   0.737800    ...       1.398540
# 25    3.151929   4.124438   3.586487   3.954608    ...       8.335151
# 26    0.310159   0.371216   0.371151   0.407085    ...       1.105608
# 27    0.700749   0.694001   0.670372   0.743448    ...       1.835266
# 28    0.816330   0.766085   0.872454   1.134077    ...       4.525009
# 29    3.798174   3.482289   3.254787   4.573085    ...      14.139046
# 30         NaN        NaN        NaN        NaN    ...       0.698568
# ..         ...        ...        ...        ...    ...            ...
# 216        NaN        NaN        NaN        NaN    ...       4.554232
# 217   0.028785   0.030485   0.032119   0.025001    ...       0.018738
# 218   0.065171   0.079426   0.077262   0.101285    ...       0.239598
# 219   0.185877   0.242240   0.234151   0.289096    ...       3.367423
# 220        NaN        NaN        NaN        NaN    ...       0.293634
# 221        NaN        NaN        NaN        NaN    ...       8.727931
# 222        NaN        NaN        NaN        NaN    ...       0.180310
# 223   0.159435   0.153309   0.147936   0.143266    ...       1.037079
# 224   1.466683   4.201774   5.694904   4.408841    ...      21.304551
# 225   0.438885   0.608626   0.532230   0.609953    ...       2.139889
# 226   0.765934   0.869390   0.883506   0.994607    ...       3.158284
# 228   0.072968   0.091197   0.099494   0.113919    ...       0.100124
# 229   0.057791   0.063435   0.078242   0.088439    ...       0.065803
# 230        NaN        NaN        NaN        NaN    ...       6.611441
# 231   0.955719   0.982914   1.036033   1.106905    ...       3.124241
# 232   1.639285   1.710101   2.049519   1.985093    ...       1.388443
# 233  16.482762  16.968119  17.451725  18.121073    ...      19.639196
# 234        NaN        NaN        NaN        NaN    ...       5.067983
# 235   0.174273   0.215513   0.170614   0.211087    ...       1.729237
# 236   6.155748   5.973226   6.187252   5.604755    ...       7.611159
# 238   0.247579   0.314058   0.343354   0.490532    ...       0.890221
# 239   0.471728   0.864247   0.641714   1.007813    ...       0.434844
# 240        NaN        NaN        NaN        NaN    ...       0.375598
# 241   3.242364   3.358696   3.437595   3.536562    ...       4.086042
# 242   0.184019   0.208092   0.230869   0.196416    ...       0.809850
# 243   0.537606   0.658012   0.699574   0.605767    ...       0.837104
# 244   5.799844   6.170936   6.467359   6.332753    ...       7.633688
# 245   0.139446   0.116926   0.142290   0.134675    ...       0.034964
# 246        NaN   0.950434   1.100197   0.953158    ...       0.176767
# 247        NaN   1.045374   1.179176   1.323656    ...       0.940195
#
#           2003       2004       2005       2006       2007       2008  \
# 0    24.909066  24.510543  24.964531  24.766706  25.613715  24.750133
# 1     7.159140   7.208829   7.088128   6.553477   6.350868   6.296125
# 2     0.046108   0.040727   0.054855   0.065816   0.088141   0.158962
# 3     0.543084   1.086605   1.069417   1.200877   1.311096   1.369425
# 4     1.412697   1.376213   1.412498   1.291548   1.507536   1.580113
# 5     3.797800   4.094269   4.206789   4.285595   4.181153   4.373573
# 6    29.467089  28.481437  25.914587  23.954519  23.195067  23.033600
# 7     3.475035   4.032407   4.111635   4.404525   4.496834   4.744178
# %% [markdown]
# ## Removing rows with invalid country names

# %%
df_co2['Country Name'].unique()
# Out:
# array([u'Aruba', u'Andorra', u'Afghanistan', u'Angola', u'Albania',
#        u'Arab World', u'United Arab Emirates', u'Argentina', u'Armenia',
#        u'Antigua and Barbuda', u'Australia', u'Austria', u'Azerbaijan',
#        u'Burundi', u'Belgium', u'Benin', u'Burkina Faso', u'Bangladesh',
#        u'Bulgaria', u'Bahrain', u'Bahamas, The', u'Bosnia and Herzegovina',
#        u'Belarus', u'Belize', u'Bermuda', u'Bolivia', u'Brazil',
#        u'Barbados', u'Brunei Darussalam', u'Bhutan', u'Botswana',
#        u'Central African Republic', u'Canada',
#        u'Central Europe and the Baltics', u'Switzerland', u'Chile',
#        u'China', u"Cote d'Ivoire", u'Cameroon', u'Congo, Rep.',
#        u'Colombia', u'Comoros', u'Cabo Verde', u'Costa Rica',
#        u'Caribbean small states', u'Cuba', u'Cayman Islands', u'Cyprus',
#        u'Czech Republic', u'Germany', u'Djibouti', u'Dominica', u'Denmark',
#        u'Dominican Republic', u'Algeria',
#        u'East Asia & Pacific (developing only)',
#        u'East Asia & Pacific (all income levels)',
#        u'Europe & Central Asia (developing only)',
#        u'Europe & Central Asia (all income levels)', u'Ecuador',
#        u'Egypt, Arab Rep.', u'Euro area', u'Eritrea', u'Spain', u'Estonia',
#        u'Ethiopia', u'European Union',
#        u'Fragile and conflict affected situations', u'Finland', u'Fiji',
#        u'France', u'Faeroe Islands', u'Micronesia, Fed. Sts.', u'Gabon',
#        u'United Kingdom', u'Georgia', u'Ghana', u'Guinea', u'Gambia, The',
#        u'Guinea-Bissau', u'Equatorial Guinea', u'Greece', u'Grenada',
#        u'Greenland', u'Guatemala', u'Guyana', u'High income',
#        u'Hong Kong SAR, China', u'Honduras',
#        u'Heavily indebted poor countries (HIPC)', u'Croatia', u'Haiti',
#        u'Hungary', u'Indonesia', u'India', u'Ireland',
#        u'Iran, Islamic Rep.', u'Iraq', u'Iceland', u'Israel', u'Italy',
#        u'Jamaica', u'Jordan', u'Japan', u'Kazakhstan', u'Kenya',
#        u'Kyrgyz Republic', u'Cambodia', u'Kiribati',
#        u'St. Kitts and Nevis', u'Korea, Rep.', u'Kuwait',
#        u'Latin America & Caribbean (developing only)', u'Lao PDR',
#        u'Lebanon', u'Liberia', u'Libya', u'St. Lucia',
#        u'Latin America & Caribbean (all income levels)',
#        u'Least developed countries: UN classification', u'Low income',
#        u'Liechtenstein', u'Sri Lanka', u'Lower middle income',
#        u'Low & middle income', u'Lesotho', u'Lithuania', u'Luxembourg',
#        u'Latvia', u'Macao SAR, China', u'Morocco', u'Moldova',
#        u'Madagascar', u'Maldives',
#        u'Middle East & North Africa (all income levels)', u'Mexico',
#        u'Marshall Islands', u'Middle income', u'Macedonia, FYR', u'Mali',
#        u'Malta', u'Myanmar',
#        u'Middle East & North Africa (developing only)', u'Montenegro',
#        u'Mongolia', u'Mozambique', u'Mauritania', u'Mauritius', u'Malawi',
#        u'Malaysia', u'North America', u'Namibia', u'New Caledonia',
#        u'Niger', u'Nigeria', u'Nicaragua', u'Netherlands',
#        u'High income: nonOECD', u'Norway', u'Nepal', u'New Zealand',
#        u'High income: OECD', u'OECD members', u'Oman',
#        u'Other small states', u'Pakistan', u'Panama', u'Peru',
#        u'Philippines', u'Palau', u'Papua New Guinea', u'Poland',
#        u'Korea, Dem. Rep.', u'Portugal', u'Paraguay',
#        u'Pacific island small states', u'French Polynesia', u'Qatar',
#        u'Romania', u'Russian Federation', u'Rwanda', u'South Asia',
#        u'Saudi Arabia', u'Sudan', u'Senegal', u'Singapore',
#        u'Solomon Islands', u'Sierra Leone', u'El Salvador', u'Somalia',
#        u'Serbia', u'Sub-Saharan Africa (developing only)',
#        u'Sub-Saharan Africa (all income levels)', u'Small states',
#        u'Sao Tome and Principe', u'Suriname', u'Slovak Republic',
#        u'Slovenia', u'Sweden', u'Swaziland', u'Seychelles',
#        u'Syrian Arab Republic', u'Turks and Caicos Islands', u'Chad',
#        u'Togo', u'Thailand', u'Tajikistan', u'Turkmenistan',
#        u'Timor-Leste', u'Tonga', u'Trinidad and Tobago', u'Tunisia',
#        u'Turkey', u'Tanzania', u'Uganda', u'Ukraine',
#        u'Upper middle income', u'Uruguay', u'United States', u'Uzbekistan',
#        u'St. Vincent and the Grenadines', u'Venezuela, RB', u'Vietnam',
#        u'Vanuatu', u'West Bank and Gaza', u'World', u'Samoa',
#        u'Yemen, Rep.', u'South Africa', u'Congo, Dem. Rep.', u'Zambia',
#        u'Zimbabwe'], dtype=object)

# %% [markdown]
# ## Before merging with metadata

# %%
metadata = pd.read_csv(
    "data/co2_aac3f2a3-99c7-4ea6-a6ef-32ead3d3dbfe_v2/Metadata_Country_aac3f2a3-99c7-4ea6-a6ef-32ead3d3dbfe_v2.csv",
    encoding = "utf-8"
)

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 6 columns):
# ﻿"Country Name"    247 non-null object
# Country Code       247 non-null object
# Region             214 non-null object
# IncomeGroup        214 non-null object
# SpecialNotes       164 non-null object
# Unnamed: 5         0 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 11.6+ KB

# %%
metadata.head()
# Out:
#   ﻿"Country Name" Country Code                     Region  \
# 0           Aruba          ABW  Latin America & Caribbean
# 1     Afghanistan          AFG                 South Asia
# 2          Angola          AGO         Sub-Saharan Africa
# 3         Albania          ALB      Europe & Central Asia
# 4         Andorra          AND      Europe & Central Asia
#
#             IncomeGroup                                       SpecialNotes  \
# 0  High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1            Low income  Fiscal year end: March 20; reporting period fo...
# 2   Upper middle income  April 2013 database update: Based on IMF data,...
# 3   Upper middle income                                                NaN
# 4  High income: nonOECD                                                NaN
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
#metadata['"Country Name"']

# %%
metadata.iloc[:,0].unique()
# Out:
# array([u'Aruba', u'Afghanistan', u'Angola', u'Albania', u'Andorra',
#        u'Arab World', u'United Arab Emirates', u'Argentina', u'Armenia',
#        u'American Samoa', u'Antigua and Barbuda', u'Australia', u'Austria',
#        u'Azerbaijan', u'Burundi', u'Belgium', u'Benin', u'Burkina Faso',
#        u'Bangladesh', u'Bulgaria', u'Bahrain', u'Bahamas, The',
#        u'Bosnia and Herzegovina', u'Belarus', u'Belize', u'Bermuda',
#        u'Bolivia', u'Brazil', u'Barbados', u'Brunei Darussalam', u'Bhutan',
#        u'Botswana', u'Central African Republic', u'Canada',
#        u'Central Europe and the Baltics', u'Switzerland',
#        u'Channel Islands', u'Chile', u'China', u"C\xf4te d'Ivoire",
#        u'Cameroon', u'Congo, Dem. Rep.', u'Congo, Rep.', u'Colombia',
#        u'Comoros', u'Cabo Verde', u'Costa Rica', u'Caribbean small states',
#        u'Cuba', u'Cura\xe7ao', u'Cayman Islands', u'Cyprus',
#        u'Czech Republic', u'Germany', u'Djibouti', u'Dominica', u'Denmark',
#        u'Dominican Republic', u'Algeria', u'East Asia & Pacific',
#        u'East Asia & Pacific (all income levels)',
#        u'Europe & Central Asia',
#        u'Europe & Central Asia (all income levels)', u'Ecuador',
#        u'Egypt, Arab Rep.', u'Euro area', u'Eritrea', u'Spain', u'Estonia',
#        u'Ethiopia', u'European Union',
#        u'Fragile and conflict affected situations', u'Finland', u'Fiji',
#        u'France', u'Faeroe Islands', u'Micronesia, Fed. Sts.', u'Gabon',
#        u'United Kingdom', u'Georgia', u'Ghana', u'Guinea', u'Gambia, The',
#        u'Guinea-Bissau', u'Equatorial Guinea', u'Greece', u'Grenada',
#        u'Greenland', u'Guatemala', u'Guam', u'Guyana', u'High income',
#        u'Hong Kong SAR, China', u'Honduras',
#        u'Heavily indebted poor countries (HIPC)', u'Croatia', u'Haiti',
#        u'Hungary', u'Indonesia', u'Isle of Man', u'India', u'Ireland',
#        u'Iran, Islamic Rep.', u'Iraq', u'Iceland', u'Israel', u'Italy',
#        u'Jamaica', u'Jordan', u'Japan', u'Kazakhstan', u'Kenya',
#        u'Kyrgyz Republic', u'Cambodia', u'Kiribati',
#        u'St. Kitts and Nevis', u'Korea, Rep.', u'Kosovo', u'Kuwait',
#        u'Latin America & Caribbean', u'Lao PDR', u'Lebanon', u'Liberia',
#        u'Libya', u'St. Lucia',
#        u'Latin America & Caribbean (all income levels)',
#        u'Least developed countries: UN classification', u'Low income',
#        u'Liechtenstein', u'Sri Lanka', u'Lower middle income',
#        u'Low & middle income', u'Lesotho', u'Lithuania', u'Luxembourg',
#        u'Latvia', u'Macao SAR, China', u'St. Martin (French part)',
#        u'Morocco', u'Monaco', u'Moldova', u'Madagascar', u'Maldives',
#        u'Middle East & North Africa (all income levels)', u'Mexico',
#        u'Marshall Islands', u'Middle income', u'Macedonia, FYR', u'Mali',
#        u'Malta', u'Myanmar', u'Middle East & North Africa', u'Montenegro',
#        u'Mongolia', u'Northern Mariana Islands', u'Mozambique',
#        u'Mauritania', u'Mauritius', u'Malawi', u'Malaysia',
#        u'North America', u'Namibia', u'New Caledonia', u'Niger',
#        u'Nigeria', u'Nicaragua', u'Netherlands', u'High income: nonOECD',
#        u'Norway', u'Nepal', u'New Zealand', u'High income: OECD',
#        u'OECD members', u'Oman', u'Other small states', u'Pakistan',
#        u'Panama', u'Peru', u'Philippines', u'Palau', u'Papua New Guinea',
#        u'Poland', u'Puerto Rico', u'Korea, Dem. Rep.', u'Portugal',
#        u'Paraguay', u'West Bank and Gaza', u'Pacific island small states',
#        u'French Polynesia', u'Qatar', u'Romania', u'Russian Federation',
#        u'Rwanda', u'South Asia', u'Saudi Arabia', u'Sudan', u'Senegal',
#        u'Singapore', u'Solomon Islands', u'Sierra Leone', u'El Salvador',
#        u'San Marino', u'Somalia', u'Serbia', u'Sub-Saharan Africa',
#        u'South Sudan', u'Sub-Saharan Africa (all income levels)',
#        u'Small states', u'S\xe3o Tom\xe9 and Principe', u'Suriname',
#        u'Slovak Republic', u'Slovenia', u'Sweden', u'Swaziland',
#        u'Sint Maarten (Dutch part)', u'Seychelles',
#        u'Syrian Arab Republic', u'Turks and Caicos Islands', u'Chad',
#        u'Togo', u'Thailand', u'Tajikistan', u'Turkmenistan',
#        u'Timor-Leste', u'Tonga', u'Trinidad and Tobago', u'Tunisia',
#        u'Turkey', u'Tuvalu', u'Tanzania', u'Uganda', u'Ukraine',
#        u'Upper middle income', u'Uruguay', u'United States', u'Uzbekistan',
#        u'St. Vincent and the Grenadines', u'Venezuela, RB',
#        u'Virgin Islands (U.S.)', u'Vietnam', u'Vanuatu', u'World',
#        u'Samoa', u'Yemen, Rep.', u'South Africa', u'Zambia', u'Zimbabwe'], dtype=object)

# %% [markdown]
# ### Change the column name

# %%
metadata.columns = ['Country Name', 'Country Code', 'Region','IncomeGroup', 'SpecialNotes', 'Unnamed: 5']

# %%
metadata[metadata['Country Name'] == 'East Asia & Pacific (all income levels)']
# Out:
#                                Country Name Country Code Region IncomeGroup  \
# 60  East Asia & Pacific (all income levels)          EAS    NaN         NaN
#
#                                          SpecialNotes  Unnamed: 5
# 60  East Asia and Pacific regional aggregate (incl...         NaN

# %%
# show the first 3 records without region information
metadata[metadata['Region'].isnull()][:3]
# Out:
#                       Country Name Country Code Region IncomeGroup  \
# 5                       Arab World          ARB    NaN         NaN
# 34  Central Europe and the Baltics          CEB    NaN         NaN
# 47          Caribbean small states          CSS    NaN         NaN
#
#                                          SpecialNotes  Unnamed: 5
# 5   Arab World aggregate. Arab World is composed o...         NaN
# 34          Central Europe and the Baltics aggregate.         NaN
# 47  Caribbean small states aggregate. Includes Ant...         NaN

# %%
removed_country_code = metadata[metadata['Region'].isnull()].loc[:,'Country Code']

# %%
removed_country_code.shape
# Out:
# (33,)

# %%
df_co2.shape
# Out:
# (232, 55)

# %%
removed_rows_countries = df_co2[df_co2['Country Code'].isin(removed_country_code)]

# %%
removed_rows_countries.shape
# Out:
# (33, 55)

# %%
df_co2[~df_co2['Country Code'].isin(removed_country_code)]
# Out:
#                        Country Name Country Code       1960       1961  \
# 0                             Aruba          ABW        NaN        NaN
# 1                           Andorra          AND        NaN        NaN
# 2                       Afghanistan          AFG   0.046068   0.053615
# 3                            Angola          AGO   0.104357   0.084718
# 4                           Albania          ALB   1.258195   1.374186
# 6              United Arab Emirates          ARE   0.118786   0.108937
# 7                         Argentina          ARG   2.367473   2.442616
# 8                           Armenia          ARM        NaN        NaN
# 10              Antigua and Barbuda          ATG   0.670617   0.860441
# 11                        Australia          AUS   8.582937   8.641569
# 12                          Austria          AUT   4.373319   4.496362
# 13                       Azerbaijan          AZE        NaN        NaN
# 14                          Burundi          BDI        NaN        NaN
# 15                          Belgium          BEL   9.941594  10.103872
# 16                            Benin          BEN   0.066354   0.052046
# 17                     Burkina Faso          BFA   0.009112   0.018730
# 18                       Bangladesh          BGD        NaN        NaN
# 19                         Bulgaria          BGR   2.833901   3.269920
# 20                          Bahrain          BHR   3.542864  10.547396
# 21                     Bahamas, The          BHS   3.749831   4.746699
# 22           Bosnia and Herzegovina          BIH        NaN        NaN
# 23                          Belarus          BLR        NaN        NaN
# 24                           Belize          BLZ   0.477951   0.387219
# 25                          Bermuda          BMU   3.551374   3.868484
# 26                          Bolivia          BOL   0.272038   0.276621
# 27                           Brazil          BRA   0.647068   0.658625
# 28                         Barbados          BRB   0.746313   0.838899
# 29                Brunei Darussalam          BRN   4.078179   3.552009
# 30                           Bhutan          BTN        NaN        NaN
# 31                         Botswana          BWA        NaN        NaN
# ..                              ...          ...        ...        ...
# 214                      Seychelles          SYC        NaN        NaN
# 215            Syrian Arab Republic          SYR   0.701818   0.646400
# 216        Turks and Caicos Islands          TCA        NaN        NaN
# 217                            Chad          TCD   0.018319   0.016769
# 218                            Togo          TGO   0.041762   0.057386
# 219                        Thailand          THA   0.135586   0.146944
# 220                      Tajikistan          TJK        NaN        NaN
# 221                    Turkmenistan          TKM        NaN        NaN
# 222                     Timor-Leste          TLS        NaN        NaN
# 223                           Tonga          TON   0.178588   0.172592
# 224             Trinidad and Tobago          TTO   3.042576   5.318141
# 225                         Tunisia          TUN   0.409211   0.413220
# 226                          Turkey          TUR   0.610473   0.615079
# 228                        Tanzania          TZA   0.082261   0.067872
# 229                          Uganda          UGA   0.062123   0.058093
# 230                         Ukraine          UKR        NaN        NaN
# 232                         Uruguay          URY   1.701583   1.602723
# 233                   United States          USA  15.999779  15.681256
# 234                      Uzbekistan          UZB        NaN        NaN
# 235  St. Vincent and the Grenadines          VCT   0.135902   0.133923
# 236                   Venezuela, RB          VEN   7.005107   6.136886
# 238                         Vietnam          VNM   0.215631   0.225435
# 239                         Vanuatu          VUT        NaN        NaN
# 240              West Bank and Gaza          PSE        NaN        NaN
# 242                           Samoa          WSM   0.135009   0.163529
# 243                     Yemen, Rep.          YEM   0.703403   0.507631
# 244                    South Africa          ZAF   5.629718   5.694383
# 245                Congo, Dem. Rep.          COD   0.152228   0.150782
# 246                          Zambia          ZMB        NaN        NaN
# 247                        Zimbabwe          ZWE        NaN        NaN
#
#           1962       1963       1964       1965       1966       1967  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 
# 224  36.816763  35.455298  36.569448  38.337841  37.140054
# 225   2.357974   2.403508   2.374157   2.535619   2.402456
# 226   4.094889   4.055397   3.898959   4.121155   4.383105
# 228   0.144041   0.147982   0.139973   0.150059   0.154935
# 229   0.104293   0.101919   0.105320   0.108297   0.110887
# 230   6.910708   6.724046   5.647014   6.638152   6.262352
# 232   1.796306   2.471054   2.401221   1.912605   2.296201
# 233  19.237460  18.489234  17.192379  17.484792  17.020216
# 234   4.391447   4.434466   3.912053   3.693268   3.914921
# 235   2.084879   2.116255   2.114512   2.146877   2.179923
# 236   5.868518   6.604892   6.525293   6.811756   6.416334
# 238   1.352791   1.497496   1.636371   1.761695   1.971889
# 239   0.433459   0.406839   0.508463   0.496591   0.591266
# 240   0.665297   0.570947   0.564578   0.534015   0.572407
# 242   1.026224   1.039490   1.072106   1.103871   1.252110
# 243   0.981422   0.989905   1.026251   1.090060   0.919968
# 244   9.063326   9.506481   9.545495   8.957154   9.257216
# 245   0.047312   0.048411   0.045604   0.049328   0.050303
# 246   0.150265   0.164692   0.184058   0.192079   0.212450
# 247   0.731867   0.569255   0.600521   0.646073   0.691698
#
#          co2_emissions_unit
# 0    metric tons per capita
# 1    metric tons per capita
# 2    metric tons per capita
# 3    metric tons per capita
# 4    metric tons per capita
# 6    metric tons per capita
# 7    metric tons per capita
# 8    metric tons per capita
# 10   metric tons per capita
# 11   metric tons per capita
# 12   metric tons per capita
# 13   metric tons per capita
# 14   metric tons per capita
# 15   metric tons per capita
# 16   metric tons per capita
# 17   metric tons per capita
# 18   metric tons per capita
# 19   metric tons per capita
# 20   metric tons per capita
# 21   metric tons per capita
# 22   metric tons per capita
# 23   metric tons per capita
# 24   metric tons per capita
# 25   metric tons per capita
# 26   metric tons per capita
# 27   metric tons per capita
# 28   metric tons per capita
# 29   metric tons per capita
# 30   metric tons per capita
# 31   metric tons per capita
# ..                      ...
# 214  metric tons per capita
# 215  metric tons per capita
# 216  metric tons per capita
# 217  metric tons per capita
# 218  metric tons per capita
# 219  metric tons per capita
# 220  metric tons per capita
# 221  metric tons per capita
# 222  metric tons per capita
# 223  metric tons per capita
# 224  metric tons per capita
# 225  metric tons per capita
# 226  metric tons per capita
# 228  metric tons per capita
# 229  metric tons per capita
# 230  metric tons per capita
# 232  metric tons per capita
# 233  metric tons per capita
# 234  metric tons per capita
# 235  metric tons per capita
# 236  metric tons per capita
# 238  metric tons per capita
# 239  metric tons per capita
# 240  metric tons per capita
# 242  metric tons per capita
# 243  metric tons per capita
# 244  metric tons per capita
# 245  metric tons per capita
# 246  metric tons per capita
# 247  metric tons per capita
#
# [199 rows x 55 columns]

# %%
df_co2 = df_co2[~df_co2['Country Code'].isin(removed_country_code)]

# %%
df_co2.shape
# Out:
# (199, 55)

# %% [markdown]
# ### Recap

# %%
df_co2.head()
# Out:
#   Country Name Country Code      1960      1961      1962      1963      1964  \
# 0        Aruba          ABW       NaN       NaN       NaN       NaN       NaN
# 1      Andorra          AND       NaN       NaN       NaN       NaN       NaN
# 2  Afghanistan          AFG  0.046068  0.053615  0.073781  0.074251  0.086317
# 3       Angola          AGO  0.104357  0.084718  0.216025  0.206877  0.216174
# 4      Albania          ALB  1.258195  1.374186  1.439956  1.181681  1.111742
#
#        1965      1966      1967           ...                 2003       2004  \
# 0       NaN       NaN       NaN           ...            24.909066  24.510543
# 1       NaN       NaN       NaN           ...             7.159140   7.208829
# 2  0.101499  0.107674  0.123782           ...             0.046108   0.040727
# 3  0.206089  0.265164  0.166659           ...             0.543084   1.086605
# 4  1.166099  1.333055  1.363746           ...             1.412697   1.376213
#
#         2005       2006       2007       2008       2009       2010  \
# 0  24.964531  24.766706  25.613715  24.750133  24.876706  24.182702
# 1   7.088128   6.553477   6.350868   6.296125   6.049173   6.124770
# 2   0.054855   0.065816   0.088141   0.158962   0.249074   0.302936
# 3   1.069417   1.200877   1.311096   1.369425   1.430873   1.401654
# 4   1.412498   1.291548   1.507536   1.580113   1.533178   1.515632
#
#         2011      co2_emissions_unit
# 0  23.922412  metric tons per capita
# 1   5.968685  metric tons per capita
# 2   0.425262  metric tons per capita
# 3   1.354008  metric tons per capita
# 4   1.607038  metric tons per capita
#
# [5 rows x 55 columns]

# %% [markdown]
# ### putting all the years in rows

# %%
pd.melt(df_co2,id_vars=['Country Name', 'Country Code', 'Indicator Name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-161-721dd1cde9aa> in <module>()
# ----> 1 pd.melt(df_co2,id_vars=['Country Name', 'Country Code', 'Indicator Name'])
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/reshape.pyc in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#     784     mdata = {}
#     785     for col in id_vars:
# --> 786         mdata[col] = np.tile(frame.pop(col).values, K)
#     787
#     788     mcolumns = id_vars + var_name + [value_name]
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/generic.pyc in pop(self, item)
#     503         Return item and drop from frame. Raise KeyError if not found.
#     504         """
# --> 505         result = self[item]
#     506         del self[item]
#     507         try:
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'Indicator Name'

# %%
df_co2 = pd.melt(df_co2,id_vars=['Country Name', 'Country Code', 'Indicator Name'])

# %%
df_co2.columns

# %%
df_co2.rename(columns={'variable': 'year'})

# %%
df_co2.rename(columns={'variable': 'year'}, inplace=True)

# %% [markdown]
# ### ex: change column name 'value' to 'co2_emissions'

# %%
df_co2.rename(columns={'value': 'co2_emissions'}, inplace=True)

# %%
df_co2.info()

# %%
#create a unit column
df_co2['co2_emissions_unit'] = 'metric tons per capita'

# %%
df_co2 = df_co2.drop('Indicator Name', axis = 1)

# %%
df_co2['year'].astype(int)

# %%
df_co2['year'] = df_co2['year'].astype(int)

# %%
df_co2.head()

# %%
df_co2.info()

# %%
metadata.head()

# %%
metadata.drop(['Unnamed: 5', 'Country Name'], axis= 1)

# %%
metadata = metadata.drop(['Unnamed: 5', 'Country Name'], axis= 1)

# %% [markdown]
# ## Merge co2 data with metadata

# %% [markdown]
# <img src = 'http://www.codeproject.com/KB/database/Visual_SQL_Joins/Visual_SQL_JOINS_orig.jpg', width = 800>

# %%
pd.merge(df_co2, metadata, on ='Country Code', how = 'left')
# Out:
#                      Country Name_x Country Code       1960       1961  \
# 0                             Aruba          ABW        NaN        NaN
# 1                           Andorra          AND        NaN        NaN
# 2                       Afghanistan          AFG   0.046068   0.053615
# 3                            Angola          AGO   0.104357   0.084718
# 4                           Albania          ALB   1.258195   1.374186
# 5              United Arab Emirates          ARE   0.118786   0.108937
# 6                         Argentina          ARG   2.367473   2.442616
# 7                           Armenia          ARM        NaN        NaN
# 8               Antigua and Barbuda          ATG   0.670617   0.860441
# 9                         Australia          AUS   8.582937   8.641569
# 10                          Austria          AUT   4.373319   4.496362
# 11                       Azerbaijan          AZE        NaN        NaN
# 12                          Burundi          BDI        NaN        NaN
# 13                          Belgium          BEL   9.941594  10.103872
# 14                            Benin          BEN   0.066354   0.052046
# 15                     Burkina Faso          BFA   0.009112   0.018730
# 16                       Bangladesh          BGD        NaN        NaN
# 17                         Bulgaria          BGR   2.833901   3.269920
# 18                          Bahrain          BHR   3.542864  10.547396
# 19                     Bahamas, The          BHS   3.749831   4.746699
# 20           Bosnia and Herzegovina          BIH        NaN        NaN
# 21                          Belarus          BLR        NaN        NaN
# 22                           Belize          BLZ   0.477951   0.387219
# 23                          Bermuda          BMU   3.551374   3.868484
# 24                          Bolivia          BOL   0.272038   0.276621
# 25                           Brazil          BRA   0.647068   0.658625
# 26                         Barbados          BRB   0.746313   0.838899
# 27                Brunei Darussalam          BRN   4.078179   3.552009
# 28                           Bhutan          BTN        NaN        NaN
# 29                         Botswana          BWA        NaN        NaN
# ..                              ...          ...        ...        ...
# 169                      Seychelles          SYC        NaN        NaN
# 170            Syrian Arab Republic          SYR   0.701818   0.646400
# 171        Turks and Caicos Islands          TCA        NaN        NaN
# 172                            Chad          TCD   0.018319   0.016769
# 173                            Togo          TGO   0.041762   0.057386
# 174                        Thailand          THA   0.135586   0.146944
# 175                      Tajikistan          TJK        NaN        NaN
# 176                    Turkmenistan          TKM        NaN        NaN
# 177                     Timor-Leste          TLS        NaN        NaN
# 178                           Tonga          TON   0.178588   0.172592
# 25      ...       1.990429   1.866522   2.113415   2.191394
# 26      ...       5.871114   5.833678   5.430338   5.580178
# 27      ...      26.338271  22.149029  21.873222  24.392013
# 28      ...       0.606779   0.549146   0.677145   0.766206
# 29      ...       2.530551   2.192295   2.555293   2.323345
# ..      ...            ...        ...        ...        ...
# 169     ...       7.970272   8.485120   7.679581   6.835706
# 170     ...       3.360814   3.012318   2.971741   2.736991
# 171     ...       6.094875   5.940523   6.152486   6.010149
# 172     ...       0.045756   0.042689   0.043463   0.043830
# 173     ...       0.285948   0.270614   0.269107   0.319444
# 174     ...       3.984060   4.198512   4.470426   4.534492
# 175     ...       0.409462   0.382775   0.373873   0.358948
# 176     ...      11.557572  10.110661  11.358111  12.183667
# 177     ...       0.185017   0.174891   0.171932   0.163648
# 178     ...       1.176967   1.276514   1.128883   0.983562
# 179     ...      35.455298  36.569448  38.337841  37.140054
# 180     ...       2.403508   2.374157   2.535619   2.402456
# 181     ...       4.055397   3.898959   4.121155   4.383105
# 182     ...       0.147982   0.139973   0.150059   0.154935
# 183     ...       0.101919   0.105320   0.108297   0.110887
# 184     ...       6.724046   5.647014   6.638152   6.262352
# 185     ...       2.471054   2.401221   1.912605   2.296201
# 186     ...      18.489234  17.192379  17.484792  17.020216
# 187     ...       4.434466   3.912053   3.693268   3.914921
# 188     ...       2.116255   2.114512   2.146877   2.179923
# 189     ...       6.604892   6.525293   6.811756   6.416334
# 190     ...       1.497496   1.636371   1.761695   1.971889
# 191     ...       0.406839   0.508463   0.496591   0.591266
# 192     ...       0.570947   0.564578   0.534015   0.572407
# 193     ...       1.039490   1.072106   1.103871   1.252110
# 194     ...       0.989905   1.026251   1.090060   0.919968
# 195     ...       9.506481   9.545495   8.957154   9.257216
# 196     ...       0.048411   0.045604   0.049328   0.050303
# 197     ...       0.164692   0.184058   0.192079   0.212450
# 198     ...       0.569255   0.600521   0.646073   0.691698
#
#          co2_emissions_unit                  Country Name_y  \
# 0    metric tons per capita                           Aruba
# 1    metric tons per capita                         Andorra
# 2    metric tons per capita                     Afghanistan
# 3    metric tons per capita                          Angola
# 4    metric tons per capita                         Albania
# 5    metric tons per capita            United Arab Emirates
# 6    metric tons per capita                       Argentina
# 7    metric tons per capita                         Armenia
# 8    metric tons per capita             Antigua and Barbuda
# 9    metric tons per capita                       Australia
# 10   metric tons per capita                         Austria
# 11   metric tons per capita                      Azerbaijan
# 12   metric tons per capita                         Burundi
# 13   metric tons per capita                         Belgium
# 14   metric tons per capita                           Benin
# 15   metric tons per capita                    Burkina Faso
# 16   metric tons per capita                      Bangladesh
# 17   metric tons per capita                        Bulgaria
# 18   metric tons per capita                         Bahrain
# 19   metric tons per capita                    Bahamas, The
# 20   metric tons per capita          Bosnia and Herzegovina
# 21   metric tons per capita                         Belarus
# 22   metric tons per capita                          Belize
# 23   metric tons per capita                         Bermuda
# 24   metric tons per capita                         Bolivia
# 25   metric tons per capita                          Brazil
# 26   metric tons per capita                        Barbados
# 27   metric tons per capita               Brunei Darussalam
# 28   metric tons per capita                          Bhutan
# 29   metric tons per capita                        Botswana
# ..                      ...                             ...
# 169  metric tons per capita                      Seychelles
# 170  metric tons per capita            Syrian Arab Republic
# 171  metric tons per capita        Turks and Caicos Islands
# 172  metric tons per capita                            Chad
# 173  metric tons per capita                            Togo
# 174  metric tons per capita                        Thailand
# 175  metric tons per capita                      Tajikistan
# 176  metric tons per capita                    Turkmenistan
# 177  metric tons per capita                     Timor-Leste
# 178  metric tons per capita                           Tonga
# 179  metric tons per capita             Trinidad and Tobago
# 180  metric tons per capita                         Tunisia
# 181  metric tons per capita                          Turkey
# 182  metric tons per capita                        Tanzania
# 183  metric tons per capita                          Uganda
# 184  metric tons per capita                         Ukraine
# 185  metric tons per capita                         Uruguay
# 186  metric tons per capita                   United States
# 187  metric tons per capita                      Uzbekistan
# 188  metric tons per capita  St. Vincent and the Grenadines
# 189  metric tons per capita                   Venezuela, RB
# 190  metric tons per capita                         Vietnam
# 191  metric tons per capita                         Vanuatu
# 192  metric tons per capita              West Bank and Gaza
# 193  metric tons per capita                           Samoa
# 194  metric tons per capita                     Yemen, Rep.
# 195  metric tons per capita                    South Africa
# 196  metric tons per capita                Congo, Dem. Rep.
# 197  metric tons per capita                          Zambia
# 198  metric tons per capita                        Zimbabwe
#
#                          Region           IncomeGroup  \
# 0     Latin America & Caribbean  High income: nonOECD
# 1         Europe & Central Asia  High income: nonOECD
# 2                    South Asia            Low income
# 3            Sub-Saharan Africa   Upper middle income
# 4         Europe & Central Asia   Upper middle income
# 5    Middle East & North Africa  High income: nonOECD
# 6     Latin America & Caribbean  High income: nonOECD
# 7         Europe & Central Asia   Lower middle income
# 8     Latin America & Caribbean  High income: nonOECD
# 9           East Asia & Pacific     High income: OECD
# 10        Europe & Central Asia     High income: OECD
# 11        Europe & Central Asia   Upper middle income
# 12           Sub-Saharan Africa            Low income
# 13        Europe & Central Asia     High income: OECD
# 14           Sub-Saharan Africa            Low income
# 15           Sub-Saharan Africa            Low income
# 16                   South Asia   Lower middle income
# 17        Europe & Central Asia   Upper middle income
# 18   Middle East & North Africa  High income: nonOECD
# 19    Latin America & Caribbean  High income: nonOECD
# 20        Europe & Central Asia   Upper middle income
# 21        Europe & Central Asia   Upper middle income
# 22    Latin America & Caribbean   Upper middle income
# 23                North America  High income: nonOECD
# 24    Latin America & Caribbean   Lower middle income
# 25    Latin America & Caribbean   Upper middle income
# 26    Latin America & Caribbean  High income: nonOECD
# 27          East Asia & Pacific  High income: nonOECD
# 28                   South Asia   Lower middle income
# 29           Sub-Saharan Africa   Upper middle income
# ..                          ...                   ...
# 169          Sub-Saharan Africa  High income: nonOECD
# 170  Middle East & North Africa   Lower middle income
# 171   Latin America & Caribbean  High income: nonOECD
# 172          Sub-Saharan Africa            Low income
# 173          Sub-Saharan Africa            Low income
# 174         East Asia & Pacific   Upper middle income
# 175       Europe & Central Asia   Lower middle income
# 176       Europe & Central Asia   Upper middle income
# 177         East Asia & Pacific   Lower middle income
# 178         East Asia & Pacific   Upper middle income
# 179   Latin America & Caribbean  High income: nonOECD
# 180  Middle East & North Africa   Upper middle income
# 181       Europe & Central Asia   Upper middle income
# 182          Sub-Saharan Africa            Low income
# 183          Sub-Saharan Africa            Low income
# 184       Europe & Central Asia   Lower middle income
# 185   Latin America & Caribbean  High income: nonOECD
# 186               North America     High income: OECD
# 187       Europe & Central Asia   Lower middle income
# 188   Latin America & Caribbean   Upper middle income
# 189   Latin America & Caribbean  High income: nonOECD
# 190         East Asia & Pacific   Lower middle income
# 191         East Asia & Pacific   Lower middle income
# 192  Middle East & North Africa   Lower middle income
# 193         East Asia & Pacific   Lower middle income
# 194  Middle East & North Africa   Lower middle income
# 195          Sub-Saharan Africa   Upper middle income
# 196          Sub-Saharan Africa            Low income
# 197          Sub-Saharan Africa   Lower middle income
# 198          Sub-Saharan Africa            Low income
#
#                                           SpecialNotes  Unnamed: 5
# 0    SNA data for 2000-2011 are updated from offici...         NaN
# 1                                                  NaN         NaN
# 2    Fiscal year end: March 20; reporting period fo...         NaN
# 3    April 2013 database update: Based on IMF data,...         NaN
# 4                                                  NaN         NaN
# 5    April 2013 database update: Based on data from...         NaN
# 6                   The base year has changed to 2004.         NaN
# 7                                                  NaN         NaN
# 8    April 2012 database update: Based on official ...         NaN
# 9    Fiscal year end: June 30; reporting period for...         NaN
# 10   A simple multiplier is used to convert the nat...         NaN
# 11   April 2012 database update: National accounts ...         NaN
# 12                                                 NaN         NaN
# 13   A simple multiplier is used to convert the nat...         NaN
# 14                                                 NaN         NaN
# 15                                                 NaN         NaN
# 16   Fiscal year end: June 30; reporting period for...         NaN
# 17   The new reference year for chain linked series...         NaN
# 18   Based on official government statistics; the n...         NaN
# 19                                                 NaN         NaN
# 20   Based on official government statistics for ch...         NaN
# 21                                                 NaN         NaN
# 22                                                 NaN         NaN
# 23                                                 NaN         NaN
# 24                                                 NaN         NaN
# 25                                                 NaN         NaN
# 26                                                 NaN         NaN
# 27                                                 NaN         NaN
# 28   April 2013 database update: Data were updated ...         NaN
# 29   Fiscal year end: March 31; reporting period fo...         NaN
# ..                                                 ...         ...
# 169  April 2013 database update: Based on official ...         NaN
# 170  April 2013 database update: Based on data from...         NaN
# 171                                                NaN         NaN
# 172  Based on IMF data, national accounts data have...         NaN
# 173  April 2013 database update: Based on IMF data,...         NaN
# 174  Fiscal year end: September 30; reporting perio...         NaN
# 175                                                NaN         NaN
# 176  On January 1, 2009, the Turkmen manat was rede...         NaN
# 177  Based on official government statistics, natio...         NaN
# 178  2013 national accounts estimates are based on ...         NaN
# 179                                                NaN         NaN
# 180                                                NaN         NaN
# 181                                                NaN         NaN
# 182  The new base year is 2007. Tanzania reports us...         NaN
# 183  Fiscal year end: June 30; reporting period for...         NaN
# 184                                                NaN         NaN
# 185  In 2011, the Central Bank revised national acc...         NaN
# 186  Fiscal year end: September 30; reporting perio...         NaN
# 187                                                NaN         NaN
# 188  April 2012 database update: Based on official ...         NaN
# 189                                                NaN         NaN
# 190  Based on data from the Vietnam Statistics Offi...         NaN
# 191  2013 national accounts estimates are based on ...         NaN
# 192                         The new base year is 2004.         NaN
# 193  Fiscal year ends on June 30; reporting period ...         NaN
# 194  Based on official government statistics and In...         NaN
# 195  Fiscal year end: March 31; reporting period fo...         NaN
# 196  Based on official government statistics; the n...         NaN
# 197  The new base year is 2010. National accounts d...         NaN
# 198  Fiscal year end: June 30; reporting period for...         NaN
#
# [199 rows x 60 columns]

# %%
df_merged_co2_meta = pd.merge(df_co2, metadata, on ='Country Code', how = 'left')

# %%
df_merged_co2_meta.shape
# Out:
# (199, 60)

# %%
df_merged_co2_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 198
# Data columns (total 60 columns):
# Country Name_x        199 non-null object
# Country Code          199 non-null object
# 1960                  150 non-null float64
# 1961                  151 non-null float64
# 1962                  152 non-null float64
# 1963                  153 non-null float64
# 1964                  158 non-null float64
# 1965                  158 non-null float64
# 1966                  158 non-null float64
# 1967                  158 non-null float64
# 1968                  157 non-null float64
# 1969                  158 non-null float64
# 1970                  160 non-null float64
# 1971                  161 non-null float64
# 1972                  163 non-null float64
# 1973                  163 non-null float64
# 1974                  163 non-null float64
# 1975                  163 non-null float64
# 1976                  163 non-null float64
# 1977                  163 non-null float64
# 1978                  163 non-null float64
# 1979                  163 non-null float64
# 1980                  163 non-null float64
# 1981                  163 non-null float64
# 1982                  163 non-null float64
# 1983                  163 non-null float64
# 1984                  163 non-null float64
# 1985                  163 non-null float64
# 1986                  164 non-null float64
# 1987                  164 non-null float64
# 1988                  164 non-null float64
# 1989                  164 non-null float64
# 1990                  166 non-null float64
# 1991                  167 non-null float64
# 1992                  187 non-null float64
# 1993                  187 non-null float64
# 1994                  188 non-null float64
# 1995                  191 non-null float64
# 1996                  190 non-null float64
# 1997                  192 non-null float64
# 1998                  193 non-null float64
# 1999                  193 non-null float64
# 2000                  194 non-null float64
# 2001                  194 non-null float64
# 2002                  195 non-null float64
# 2003                  195 non-null float64
# 2004                  195 non-null float64
# 2005                  197 non-null float64
# 2006                  198 non-null float64
# 2007                  199 non-null float64
# 2008                  199 non-null float64
# 2009                  199 non-null float64
# 2010                  199 non-null float64
# 2011                  199 non-null float64
# co2_emissions_unit    199 non-null object
# Country Name_y        199 non-null object
# Region                199 non-null object
# IncomeGroup           199 non-null object
# SpecialNotes          127 non-null object
# Unnamed: 5            0 non-null float64
# dtypes: float64(53), object(7)
# memory usage: 94.8+ KB

# %% [markdown]
# ### Adding population data
# 1. Remove columns
# 1. Remove rows
# 1. Reshape dataframe
# 1. Merge it with the merged df

# %%
df_population = pd.read_csv(
    "data/population_4e08cff3-c5b0-4d87-ab6e-77215af1f57c_v2/4e08cff3-c5b0-4d87-ab6e-77215af1f57c_v2.csv",
    skiprows=4,
    encoding='utf-8'
)

# %%
df_population.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54208.0
# 1      Andorra          AND  Population, total    SP.POP.TOTL    13414.0
# 2  Afghanistan          AFG  Population, total    SP.POP.TOTL  8994793.0
# 3       Angola          AGO  Population, total    SP.POP.TOTL  5270844.0
# 4      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
#
#         1961       1962       1963       1964       1965     ...       \
# 0    55435.0    56226.0    56697.0    57029.0    57360.0     ...
# 1    14376.0    15376.0    16410.0    17470.0    18551.0     ...
# 2  9164945.0  9343772.0  9531555.0  9728645.0  9935358.0     ...
# 3  5367287.0  5465905.0  5565808.0  5665701.0  5765025.0     ...
# 4  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0     ...
#
#          2007        2008        2009        2010        2011        2012  \
# 0    101218.0    101342.0    101416.0    101597.0    101936.0    102393.0
# 1     84878.0     85616.0     85474.0     84419.0     82326.0     79316.0
# 2  25877544.0  26528741.0  27207291.0  27962207.0  28809167.0  29726803.0
# 3  19183907.0  19842251.0  20520103.0  21219954.0  21942296.0  22685632.0
# 4   2970017.0   2947314.0   2927519.0   2913021.0   2904780.0   2900489.0
#
#          2013        2014  2015  Unnamed: 60
# 0    102921.0    103441.0   NaN          NaN
# 1     75902.0     72786.0   NaN          NaN
# 2  30682500.0  31627506.0   NaN          NaN
# 3  23448202.0  24227524.0   NaN          NaN
# 4   2897366.0   2894475.0   NaN          NaN
#
# [5 rows x 61 columns]

# %%
df_population.shape
# Out:
# (248, 61)

# %%
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 61 columns):
# Country Name      248 non-null object
# Country Code      248 non-null object
# Indicator Name    248 non-null object
# Indicator Code    248 non-null object
# 1960              244 non-null float64
# 1961              244 non-null float64
# 1962              244 non-null float64
# 1963              244 non-null float64
# 1964              244 non-null float64
# 1965              244 non-null float64
# 1966              244 non-null float64
# 1967              244 non-null float64
# 1968              244 non-null float64
# 1969              244 non-null float64
# 1970              244 non-null float64
# 1971              244 non-null float64
# 1972              244 non-null float64
# 1973              244 non-null float64
# 1974              244 non-null float64
# 1975              244 non-null float64
# 1976              244 non-null float64
# 1977              244 non-null float64
# 1978              244 non-null float64
# 1979              244 non-null float64
# 1980              244 non-null float64
# 1981              244 non-null float64
# 1982              244 non-null float64
# 1983              244 non-null float64
# 1984              244 non-null float64
# 1985              244 non-null float64
# 1986              244 non-null float64
# 1987              244 non-null float64
# 1988              244 non-null float64
# 1989              244 non-null float64
# 1990              246 non-null float64
# 1991              246 non-null float64
# 1992              245 non-null float64
# 1993              245 non-null float64
# 1994              245 non-null float64
# 1995              246 non-null float64
# 1996              246 non-null float64
# 1997              246 non-null float64
# 1998              247 non-null float64
# 1999              247 non-null float64
# 2000              247 non-null float64
# 2001              247 non-null float64
# 2002              247 non-null float64
# 2003              247 non-null float64
# 2004              247 non-null float64
# 2005              247 non-null float64
# 2006              247 non-null float64
# 2007              247 non-null float64
# 2008              247 non-null float64
# 2009              247 non-null float64
# 2010              247 non-null float64
# 2011              247 non-null float64
# 2012              247 non-null float64
# 2013              247 non-null float64
# 2014              247 non-null float64
# 2015              0 non-null float64
# Unnamed: 60       0 non-null float64
# dtypes: float64(57), object(4)
# memory usage: 118.3+ KB

# %%
df_population = df_population.drop(
    ['Indicator Code', '2015', 'Unnamed: 60'],
    axis =1
)

# %%
df_population[df_population['Country Code'].isin(removed_country_code)]
# Out:
#                                        Country Name Country Code  \
# 5                                        Arab World          ARB
# 34                   Central Europe and the Baltics          CEB
# 46                           Caribbean small states          CSS
# 58            East Asia & Pacific (developing only)          EAP
# 59          East Asia & Pacific (all income levels)          EAS
# 60          Europe & Central Asia (developing only)          ECA
# 61        Europe & Central Asia (all income levels)          ECS
# 64                                        Euro area          EMU
# 69                                   European Union          EUU
# 70         Fragile and conflict affected situations          FCS
# 90                                      High income          HIC
# 93           Heavily indebted poor countries (HIPC)          HPC
# 119     Latin America & Caribbean (developing only)          LAC
# 125   Latin America & Caribbean (all income levels)          LCN
# 126    Least developed countries: UN classification          LDC
# 127                                      Low income          LIC
# 130                             Lower middle income          LMC
# 131                             Low & middle income          LMY
# 143  Middle East & North Africa (all income levels)          MEA
# 146                                   Middle income          MIC
# 151    Middle East & North Africa (developing only)          MNA
# 160                                   North America          NAC
# 167                            High income: nonOECD          NOC
# 171                               High income: OECD          OEC
# 172                                    OECD members          OED
# 174                              Other small states          OSS
# 186                     Pacific island small states          PSS
# 192                                      South Asia          SAS
# 203            Sub-Saharan Africa (developing only)          SSA
# 205          Sub-Saharan Africa (all income levels)          SSF
# 206                                    Small states          SST
# 231                             Upper middle income          UMC
# 241                                           World          WLD
#
#         Indicator Name          1960          1961          1962  \
# 5    Population, total  9.249590e+07  9.504159e+07  9.769150e+07
# 34   Population, total  9.140158e+07  9.223712e+07  9.301489e+07
# 46   Population, total  4.190810e+06  4.270928e+06  4.353408e+06
# 58   Population, total  8.964930e+08  8.957847e+08  9.073954e+08
# 59   Population, total  1.042475e+09  1.045789e+09  1.059972e+09
# 60   Population, total  1.553174e+08  1.582421e+08  1.611689e+08
# 61   Population, total  6.674890e+08  6.751817e+08  6.831143e+08
# 64   Population, total  2.653965e+08  2.678253e+08  2.703248e+08
# 69   Population, total  4.094985e+08  4.130070e+08  4.166706e+08
# 70   Population, total  1.203546e+08  1.231252e+08  1.260061e+08
# 90   Population, total  9.075975e+08  9.209709e+08  9.330254e+08
# 93   Population, total  1.624912e+08  1.663375e+08  1.703327e+08
# 119  Population, total  1.776822e+08  1.829520e+08  1.884162e+08
# 125  Population, total  2.205642e+08  2.267643e+08  2.331832e+08
# 126  Population, total  2.410728e+08  2.467331e+08  2.525859e+08
# 127  Population, total  1.571884e+08  1.606428e+08  1.641802e+08
# 130  Population, total  9.429116e+08  9.642428e+08  9.863016e+08
# 131  Population, total  2.127373e+09  2.155068e+09  2.195967e+09
# 143  Population, total  1.055126e+08  1.083926e+08  1.114190e+08
# 146  Population, total  1.970185e+09  1.994425e+09  2.031787e+09
# 151  Population, total  9.786942e+07  1.004837e+08  1.031837e+08
# 160  Population, total  1.986244e+08  2.020075e+08  2.051986e+08
# 167  Population, total  1.866767e+08  1.896568e+08  1.927296e+08
# 171  Population, total  7.209208e+08  7.313141e+08  7.402958e+08
# 172  Population, total  7.866482e+08  7.989375e+08  8.098554e+08
# 174  Population, total  6.590560e+06  6.721830e+06  6.853517e+06
# 186  Population, total  8.613780e+05  8.895360e+05  9.192760e+05
# 192  Population, total  5.720361e+08  5.841432e+08  5.967011e+08
# 203  Population, total  2.279749e+08  2.334620e+08  2.391016e+08
aN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2013  2014
# 100   NaN   NaN
#
# [1 rows x 58 columns]

# %%
df_population = df_population[df_population.mean(axis = 1).notnull()]

# %%
df_population.shape
# Out:
# (214, 58)

# %%
pd.melt(df_population,
        id_vars=['Country Name', 'Country Code', 'Indicator Name'],
        var_name='year',
        value_name= 'Total Population'
       )
# Out:
#                          Country Name Country Code     Indicator Name  year  \
# 0                               Aruba          ABW  Population, total  1960
# 1                             Andorra          AND  Population, total  1960
# 2                         Afghanistan          AFG  Population, total  1960
# 3                              Angola          AGO  Population, total  1960
# 4                             Albania          ALB  Population, total  1960
# 5                United Arab Emirates          ARE  Population, total  1960
# 6                           Argentina          ARG  Population, total  1960
# 7                             Armenia          ARM  Population, total  1960
# 8                      American Samoa          ASM  Population, total  1960
# 9                 Antigua and Barbuda          ATG  Population, total  1960
# 10                          Australia          AUS  Population, total  1960
# 11                            Austria          AUT  Population, total  1960
# 12                         Azerbaijan          AZE  Population, total  1960
# 13                            Burundi          BDI  Population, total  1960
# 14                            Belgium          BEL  Population, total  1960
# 15                              Benin          BEN  Population, total  1960
# 16                       Burkina Faso          BFA  Population, total  1960
# 17                         Bangladesh          BGD  Population, total  1960
# 18                           Bulgaria          BGR  Population, total  1960
# 19                            Bahrain          BHR  Population, total  1960
# 20                       Bahamas, The          BHS  Population, total  1960
# 21             Bosnia and Herzegovina          BIH  Population, total  1960
# 22                            Belarus          BLR  Population, total  1960
# 23                             Belize          BLZ  Population, total  1960
# 24                            Bermuda          BMU  Population, total  1960
# 25                            Bolivia          BOL  Population, total  1960
# 26                             Brazil          BRA  Population, total  1960
# 27                           Barbados          BRB  Population, total  1960
# 28                  Brunei Darussalam          BRN  Population, total  1960
# 29                             Bhutan          BTN  Population, total  1960
# ...                               ...          ...                ...   ...
# 11740        Turks and Caicos Islands          TCA  Population, total  2014
# 11741                            Chad          TCD  Population, total  2014
# 11742                            Togo          TGO  Population, total  2014
# 11743                        Thailand          THA  Population, total  2014
# 11744                      Tajikistan          TJK  Population, total  2014
# 11745                    Turkmenistan          TKM  Population, total  2014
# 11746                     Timor-Leste          TLS  Population, total  2014
# 11747                           Tonga          TON  Population, total  2014
# 11748             Trinidad and Tobago          TTO  Population, total  2014
# 11749                         Tunisia          TUN  Population, total  2014
# 11750                          Turkey          TUR  Population, total  2014
# 11751                          Tuvalu          TUV  Population, total  2014
# 11752                        Tanzania          TZA  Population, total  2014
# 11753                          Uganda          UGA  Population, total  2014
# 11754                         Ukraine          UKR  Population, total  2014
# 11755                         Uruguay          URY  Population, total  2014
# 11756                   United States          USA  Population, total  2014
# 11757                      Uzbekistan          UZB  Population, total  2014
# 11758  St. Vincent and the Grenadines          VCT  Population, total  2014
# 11759                   Venezuela, RB          VEN  Population, total  2014
# 11760           Virgin Islands (U.S.)          VIR  Population, total  2014
# 11761                         Vietnam          VNM  Population, total  2014
# 11762                         Vanuatu          VUT  Population, total  2014
# 11763              West Bank and Gaza          PSE  Population, total  2014
# 11764                           Samoa          WSM  Population, total  2014
# 11765                     Yemen, Rep.          YEM  Population, total  2014
# 11766                    South Africa          ZAF  Population, total  2014
# 11767                Congo, Dem. Rep.          COD  Population, total  2014
# 11768                          Zambia          ZMB  Population, total  2014
# 11769                        Zimbabwe          ZWE  Population, total  2014
#
#        Total Population
# 0               54208.0
# 1               13414.0
# 2             8994793.0
# 3             5270844.0
# 4             1608800.0
# 5               92612.0
# 6            20619075.0
# 7             1867396.0
# 8               20012.0
# 9               54681.0
# 10           10276477.0
# 11            7047539.0
# 12            3897889.0
# 13            2786740.0
# 14            9153489.0
# 15            2431620.0
# 16            4829291.0
# 17           48200702.0
# 18            7867374.0
# 19             162501.0
# 20             109526.0
# 21            3214520.0
# 22            8198000.0
# 23              92068.0
# 24              44400.0
# 25            3693451.0
# 26           72493585.0
# 27             230934.0
# 28              81825.0
# 29             224108.0
# ...                 ...
# 11740           33740.0
# 11741        13587053.0
# 11742         7115163.0
# 11743        67725979.0
# 11744         8295840.0
# 11745         5307188.0
# 11746         1212107.0
# 11747          105586.0
# 11748         1354483.0
# 11749        10996600.0
# 11750        75932348.0
# 11751            9893.0
# 11752        51822621.0
# 11753        37782971.0
# 11754        45362900.0
# 11755         3419516.0
# 11756       318857056.0
# 11757        30757700.0
# 11758          109360.0
# 11759        30693827.0
# 11760          104170.0
# 11761        90730000.0
# 11762          258883.0
# 11763         4294682.0
# 11764          191845.0
# 11765        26183676.0
# 11766        54001953.0
# 11767        74877030.0
# 11768        15721343.0
# 11769        15245855.0
#
# [11770 rows x 5 columns]

# %%
df_population = pd.melt(df_population,
                        id_vars=[
                            'Country Name', 'Country Code', 'Indicator Name'],
                        var_name='year',
                        value_name='Total Population'
                        )

# %%
df_population['year'] = df_population['year'].astype(int)

# %%
df_population.drop(['Country Name', 'Indicator Name'], axis = 1)
# Out:
#       Country Code  year  Total Population
# 0              ABW  1960           54208.0
# 1              AND  1960           13414.0
# 2              AFG  1960         8994793.0
# 3              AGO  1960         5270844.0
# 4              ALB  1960         1608800.0
# 5              ARE  1960           92612.0
# 6              ARG  1960        20619075.0
# 7              ARM  1960         1867396.0
# 8              ASM  1960           20012.0
# 9              ATG  1960           54681.0
# 10             AUS  1960        10276477.0
# 11             AUT  1960         7047539.0
# 12             AZE  1960         3897889.0
# 13             BDI  1960         2786740.0
# 14             BEL  1960         9153489.0
# 15             BEN  1960         2431620.0
# 16             BFA  1960         4829291.0
# 17             BGD  1960        48200702.0
# 18             BGR  1960         7867374.0
# 19             BHR  1960          162501.0
# 20             BHS  1960          109526.0
# 21             BIH  1960         3214520.0
# 22             BLR  1960         8198000.0
# 23             BLZ  1960           92068.0
# 24             BMU  1960           44400.0
# 25             BOL  1960         3693451.0
# 26             BRA  1960        72493585.0
# 27             BRB  1960          230934.0
# 28             BRN  1960           81825.0
# 29             BTN  1960          224108.0
# ...            ...   ...               ...
# 11740          TCA  2014           33740.0
# 11741          TCD  2014        13587053.0
# 11742          TGO  2014         7115163.0
# 11743          THA  2014        67725979.0
# 11744          TJK  2014         8295840.0
# 11745          TKM  2014         5307188.0
# 11746          TLS  2014         1212107.0
# 11747          TON  2014          105586.0
# 11748          TTO  2014         1354483.0
# 11749          TUN  2014        10996600.0
# 11750          TUR  2014        75932348.0
# 11751          TUV  2014            9893.0
# 11752          TZA  2014        51822621.0
# 11753          UGA  2014        37782971.0
# 11754          UKR  2014        45362900.0
# 11755          URY  2014         3419516.0
# 11756          USA  2014       318857056.0
# 11757          UZB  2014        30757700.0
# 11758          VCT  2014          109360.0
# 11759          VEN  2014        30693827.0
# 11760          VIR  2014          104170.0
# 11761          VNM  2014        90730000.0
# 11762          VUT  2014          258883.0
# 11763          PSE  2014         4294682.0
# 11764          WSM  2014          191845.0
# 11765          YEM  2014        26183676.0
# 11766          ZAF  2014        54001953.0
# 11767          COD  2014        74877030.0
# 11768          ZMB  2014        15721343.0
# 11769          ZWE  2014        15245855.0
#
# [11770 rows x 3 columns]

# %%
df_population = df_population.drop(['Country Name', 'Indicator Name'],
                                   axis = 1)

# %%
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11770 entries, 0 to 11769
# Data columns (total 3 columns):
# Country Code        11770 non-null object
# year                11770 non-null int64
# Total Population    11669 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 275.9+ KB

# %%
pd.merge(df_merged_co2_meta,df_population,
         on = ['Country Code', 'year'],
         how = 'left'
        )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-182-c44a36bd347c> in <module>()
#       1 pd.merge(df_merged_co2_meta,df_population,
#       2          on = ['Country Code', 'year'],
# ----> 3          how = 'left'
#       4         )
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      32                          right_on=right_on, left_index=left_index,
#      33                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 34                          copy=copy, indicator=indicator)
#      35     return op.get_result()
#      36 if __debug__:
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     197         (self.left_join_keys,
#     198          self.right_join_keys,
# --> 199          self.join_names) = self._get_merge_keys()
#     200
#     201     def get_result(self):
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/tools/merge.pyc in _get_merge_keys(self)
#     430                     else:
#     431                         right_keys.append(rk)
# --> 432                     left_keys.append(left[lk]._values)
#     433                     join_names.append(lk)
#     434         elif _any(self.left_on):
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/xufei/Envs/casalova-mongodb/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'year'

# %%
df_merged_co2_meta_pop = pd.merge(
    df_merged_co2_meta,df_population,
    on = ['Country Code', 'year'],
    how = 'left'
)

# %%
df_merged_co2_meta_pop.shape

# %% [markdown]
# ## Adding Natural Disaster Data From the International Disaster Database
# http://www.emdat.be/advanced_search/index.html-statistics

# %%
# !head -5 Natural_Disaster_Data.csv

# %%
df_disaster = pd.read_csv(
    'Natural_Disaster_Data.csv',
    encoding = 'utf-8'
)

# %%
df_disaster.shape

# %%
df_disaster.head()

# %%
df_disaster.index

# %%
df_disaster.reset_index()

# %%
df_disaster.reset_index(inplace=True)

# %%
df_disaster.head()

# %%
df_disaster.rename(
    columns={
        'index': 'year',
        'year' : 'disaster_type',
        'Country iso, Country name': 'country_name',
        'disaster_type': 'Country Code'
    },
    inplace = True
)

# %%
df_disaster.info()

# %% [markdown]
# ### The pre-merge check
# 1. Missing Values
# 1. Column Names

# %%
df_disaster[df_disaster.mean(axis = 1).isnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-183-c746e3d0233b> in <module>()
# ----> 1 df_disaster[df_disaster.mean(axis = 1).isnull()]
#
# NameError: name 'df_disaster' is not defined

# %%
df_disaster.drop('country_name', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-184-61a015b2ad04> in <module>()
# ----> 1 df_disaster.drop('country_name', axis = 1)
#
# NameError: name 'df_disaster' is not defined

# %%
df_disaster.drop('country_name', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-185-3dd17aefcbe9> in <module>()
# ----> 1 df_disaster.drop('country_name', axis = 1, inplace = True)
#
# NameError: name 'df_disaster' is not defined

# %%
df_disaster.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-186-59482f578bb5> in <module>()
# ----> 1 df_disaster.shape
#
# NameError: name 'df_disaster' is not defined

# %%
## add 2 columns

# %%
df_disaster['total_death_and_affected'] = df_disaster['Total affected'] + df_disaster['Total deaths']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-188-7a43dca51d69> in <module>()
# ----> 1 df_disaster['total_death_and_affected'] = df_disaster['Total affected'] + df_disaster['Total deaths']
#
# NameError: name 'df_disaster' is not defined

# %%
df_disaster['Total damage_unit'] = 'k USD'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-9de4b1cdc546> in <module>()
# ----> 1 df_disaster['Total damage_unit'] = 'k USD'
#
# NameError: name 'df_disaster' is not defined

# %%
## Merge again

# %%
pd.merge(
    df_merged_co2_meta_pop,
    df_disaster,
    on = ['Country Code', 'year'],
    how = 'left'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-191-ff1ae9016d3d> in <module>()
#       1 pd.merge(
# ----> 2     df_merged_co2_meta_pop,
#       3     df_disaster,
#       4     on = ['Country Code', 'year'],
#       5     how = 'left'
#
# NameError: name 'df_merged_co2_meta_pop' is not defined

# %%
df_merged_co2_meta_pop_dis = pd.merge(
    df_merged_co2_meta_pop,
    df_disaster,
    on = ['Country Code', 'year'],
    how = 'left'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-7a9507f6fd4c> in <module>()
#       1 df_merged_co2_meta_pop_dis = pd.merge(
# ----> 2     df_merged_co2_meta_pop,
#       3     df_disaster,
#       4     on = ['Country Code', 'year'],
#       5     how = 'left'
#
# NameError: name 'df_merged_co2_meta_pop' is not defined

# %%
df_merged_co2_meta_pop_dis.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-193-f160c1b278b3> in <module>()
# ----> 1 df_merged_co2_meta_pop_dis.shape
#
# NameError: name 'df_merged_co2_meta_pop_dis' is not defined

# %%
climate = df_merged_co2_meta_pop_dis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-194-66052087b0ca> in <module>()
# ----> 1 climate = df_merged_co2_meta_pop_dis
#
# NameError: name 'df_merged_co2_meta_pop_dis' is not defined

# %%
climate.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-195-2ed4a2ee689d> in <module>()
# ----> 1 climate.head(2)
#
# NameError: name 'climate' is not defined

# %% [markdown]
# ## Add a few columns

# %%
climate['total_co2'] = climate['co2_emissions'] * climate['Total Population']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-196-9dea902c9402> in <module>()
# ----> 1 climate['total_co2'] = climate['co2_emissions'] * climate['Total Population']
#
# NameError: name 'climate' is not defined

# %%
climate['total_co2_unit'] = 'metric_tons'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-197-c019395c6793> in <module>()
# ----> 1 climate['total_co2_unit'] = 'metric_tons'
#
# NameError: name 'climate' is not defined

# %%
climate.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-198-0720d7a4b8bd> in <module>()
# ----> 1 climate.tail()
#
# NameError: name 'climate' is not defined

# %%
climate.to_csv(
    'climate_data.csv',
    index = False,
    encoding = 'utf-8'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-199-bc56c807e996> in <module>()
# ----> 1 climate.to_csv(
#       2     'climate_data.csv',
#       3     index = False,
#       4     encoding = 'utf-8'
#       5 )
#
# NameError: name 'climate' is not defined

# %% [markdown]
# ## Exploratory Analysis

# %%
climate.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-200-c8a62db85da9> in <module>()
# ----> 1 climate.head()
#
# NameError: name 'climate' is not defined

# %%
col_names = climate.columns;
col_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-201-bcae3b3490a6> in <module>()
# ----> 1 col_names = climate.columns;
#       2 col_names
#
# NameError: name 'climate' is not defined

# %%
climate['disaster_type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-202-03cd37c9b99b> in <module>()
# ----> 1 climate['disaster_type'].value_counts()
#
# NameError: name 'climate' is not defined

# %%
climate['Region'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-203-59cc3af37b0c> in <module>()
# ----> 1 climate['Region'].value_counts()
#
# NameError: name 'climate' is not defined

# %% [markdown]
# ## Aggregating Results Using Groupby

# %%
#Groupby and split-apply-combine
by_year = climate.groupby('year')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-204-2a3f85bcc76b> in <module>()
#       1 #Groupby and split-apply-combine
# ----> 2 by_year = climate.groupby('year')
#
# NameError: name 'climate' is not defined

# %%
# It looks like a dataframe
by_year.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-205-7496869256ab> in <module>()
#       1 # It looks like a dataframe
# ----> 2 by_year.head()
#
# NameError: name 'by_year' is not defined

# %%
# but actually head() only shows the first n rows of each group
by_year.head().shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-206-4bb2e08856e9> in <module>()
#       1 # but actually head() only shows the first n rows of each group
# ----> 2 by_year.head().shape
#
# NameError: name 'by_year' is not defined

# %%
# it has a different object type
by_year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-207-5688c0803168> in <module>()
#       1 # it has a different object type
# ----> 2 by_year
#
# NameError: name 'by_year' is not defined

# %%
by_year.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-208-744a52edb4a3> in <module>()
# ----> 1 by_year.describe()
#
# NameError: name 'by_year' is not defined

# %%
by_year.describe(include =['object'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-209-6e393d131492> in <module>()
# ----> 1 by_year.describe(include =['object'])
#
# NameError: name 'by_year' is not defined

# %%
by_year.describe().iloc[:,[1,2,3,4,-2,-1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-210-2ebd7718bf22> in <module>()
# ----> 1 by_year.describe().iloc[:,[1,2,3,4,-2,-1]]
#
# NameError: name 'by_year' is not defined

# %%
# you can get a group of name
by_year.get_group(1980)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-211-80a11804b372> in <module>()
#       1 # you can get a group of name
# ----> 2 by_year.get_group(1980)
#
# NameError: name 'by_year' is not defined

# %%
# selecting a column in the groupby object
by_year['occurrence']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-212-aa5205b26e1e> in <module>()
#       1 # selecting a column in the groupby object
# ----> 2 by_year['occurrence']
#
# NameError: name 'by_year' is not defined

# %%
# you need to add a function to return a table
by_year['occurrence'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-213-08869c88e217> in <module>()
#       1 # you need to add a function to return a table
# ----> 2 by_year['occurrence'].sum()
#
# NameError: name 'by_year' is not defined

# %% [markdown]
# ### sorting results

# %%
# which year has the highest # of disasters?
by_year['occurrence'].sum().order(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-214-e3f5b64228af> in <module>()
#       1 # which year has the highest # of disasters?
# ----> 2 by_year['occurrence'].sum().order(ascending = False)
#
# NameError: name 'by_year' is not defined

# %% [markdown]
# ### In 2011, which country has the highest total co2 emissions?

# %%
df_2011 = by_year.get_group(2011)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-215-d0d308280574> in <module>()
# ----> 1 df_2011 = by_year.get_group(2011)
#
# NameError: name 'by_year' is not defined

# %%
df_2011[['Country Name', 'total_co2']].sort_index(by = 'total_co2',
                                                  ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-216-70a479b62552> in <module>()
# ----> 1 df_2011[['Country Name', 'total_co2']].sort_index(by = 'total_co2',
#       2                                                   ascending = False)
#
# NameError: name 'df_2011' is not defined

# %% [markdown]
# ### In the same year which country was the most economically affected by natural disasters?

# %%
#this seems to give you the results, but not really
df_2011[['Country Name',
         'Total damage',
         'disaster_type']].sort_index(by = 'Total damage',ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-217-cb2178141932> in <module>()
#       1 #this seems to give you the results, but not really
# ----> 2 df_2011[['Country Name',
#       3          'Total damage',
#       4          'disaster_type']].sort_index(by = 'Total damage',ascending = False)
#
# NameError: name 'df_2011' is not defined

# %%
by_country_2011 = df_2011.groupby('Country Name');
by_country_2011['Total damage'].sum().order(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-218-38963198f011> in <module>()
# ----> 1 by_country_2011 = df_2011.groupby('Country Name');
#       2 by_country_2011['Total damage'].sum().order(ascending = False)
#
# NameError: name 'df_2011' is not defined

# %% [markdown]
# ## Group by 2 variables

# %%
col_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-219-b73c15993b6f> in <module>()
# ----> 1 col_names
#
# NameError: name 'col_names' is not defined

# %%
#The total damage from all natural disasters for each country per year
by_year_country = climate.groupby(['year', 'Country Name']);
by_year_country['Total damage'].sum().order(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-220-9000d5f0114e> in <module>()
#       1 #The total damage from all natural disasters for each country per year
# ----> 2 by_year_country = climate.groupby(['year', 'Country Name']);
#       3 by_year_country['Total damage'].sum().order(ascending = False)
#
# NameError: name 'climate' is not defined

# %% [markdown]
# ### rank of total co2 emissions from high to low for each region-year combination

# %%
by_year_region = climate.groupby(['year', 'Region'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-221-1d3e3f47d271> in <module>()
# ----> 1 by_year_region = climate.groupby(['year', 'Region'])
#
# NameError: name 'climate' is not defined

# %%
by_year_region['total_co2'].sum().order(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-222-3aed3343926c> in <module>()
# ----> 1 by_year_region['total_co2'].sum().order(ascending = False)
#
# NameError: name 'by_year_region' is not defined

# %% [markdown]
# ## What if I want to see the same thing in a table with year as rows and region as columns?

# %%
by_year_region['total_co2'].sum().unstack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-223-02e140740f0f> in <module>()
# ----> 1 by_year_region['total_co2'].sum().unstack()
#
# NameError: name 'by_year_region' is not defined

# %% [markdown]
# ### Pivot Table

# %%
climate.pivot_table(values='total_co2',
                    index = 'year',
                    columns = 'Region',
                    aggfunc = 'sum')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-224-d2668a9aa8fe> in <module>()
# ----> 1 climate.pivot_table(values='total_co2',
#       2                     index = 'year',
#       3                     columns = 'Region',
#       4                     aggfunc = 'sum')
#
# NameError: name 'climate' is not defined

# %%
# turn on the margins to compare total values
climate.pivot_table(values='total_co2',
                    index = 'year',
                    columns = 'Region',
                    aggfunc = 'sum',
                    margins = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-225-b0479cdc8531> in <module>()
#       1 # turn on the margins to compare total values
# ----> 2 climate.pivot_table(values='total_co2',
#       3                     index = 'year',
#       4                     columns = 'Region',
#       5                     aggfunc = 'sum',
#
# NameError: name 'climate' is not defined

# %%
#add gradual examples of pivot table

# %%
# two levels of aggregation
climate.pivot_table(index = 'year',
                    columns = 'Region',
                    aggfunc = {'total_co2':'mean',
                               'Total damage':'sum'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-227-7ccc68f9ba07> in <module>()
#       1 # two levels of aggregation
# ----> 2 climate.pivot_table(index = 'year',
#       3                     columns = 'Region',
#       4                     aggfunc = {'total_co2':'mean',
#       5                                'Total damage':'sum'})
#
# NameError: name 'climate' is not defined

# %%
pt_total_co2 = climate.pivot_table(values='total_co2',
                    index = 'year',
                    columns = 'Region',
                    aggfunc = 'sum',)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-228-6940a846b42e> in <module>()
# ----> 1 pt_total_co2 = climate.pivot_table(values='total_co2',
#       2                     index = 'year',
#       3                     columns = 'Region',
#       4                     aggfunc = 'sum',)
#
# NameError: name 'climate' is not defined

# %% [markdown]
# ## Plotting graphs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
by_year['total_co2'].sum().plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-230-6f6dc794fd39> in <module>()
# ----> 1 by_year['total_co2'].sum().plot(kind = 'bar')
#
# NameError: name 'by_year' is not defined

# %%
from matplotlib import style
style.use('ggplot')

# %%
by_year['total_co2'].sum().plot(kind = 'bar',
                                figsize=(10, 8))
plt.title('Global CO2 Emissions')
plt.ylabel('CO2 Emission (Metric Tons)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-232-c8da1a92949e> in <module>()
# ----> 1 by_year['total_co2'].sum().plot(kind = 'bar',
#       2                                 figsize=(10, 8))
#       3 plt.title('Global CO2 Emissions')
#       4 plt.ylabel('CO2 Emission (Metric Tons)')
#
# NameError: name 'by_year' is not defined

# %%
by_year['total_co2'].sum().plot(kind = 'barh',
                                figsize=(8, 10))
plt.title('Global CO2 Emissions')
plt.xlabel('CO2 Emission (Metric Tons)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-233-dfe47aed75bd> in <module>()
# ----> 1 by_year['total_co2'].sum().plot(kind = 'barh',
#       2                                 figsize=(8, 10))
#       3 plt.title('Global CO2 Emissions')
#       4 plt.xlabel('CO2 Emission (Metric Tons)')
#
# NameError: name 'by_year' is not defined

# %%
#set default figure size
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# ### ex: plot the 20 countries with the highest CO2 emissions from 1960-2011

# %%
#global total damage over time
by_country = climate.groupby('Country Name');
by_country['total_co2'].sum().order()[-20:].plot(kind = 'barh')
plt.title('Total CO2 Emissions (1960-2011)')
plt.xlabel('CO2 Emission (Metric Tons)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-235-c7241bd0983e> in <module>()
#       1 #global total damage over time
# ----> 2 by_country = climate.groupby('Country Name');
#       3 by_country['total_co2'].sum().order()[-20:].plot(kind = 'barh')
#       4 plt.title('Total CO2 Emissions (1960-2011)')
#       5 plt.xlabel('CO2 Emission (Metric Tons)')
#
# NameError: name 'climate' is not defined

# %% [markdown]
# ### Per Capita

# %%
by_country['co2_emissions'].sum().order()[-20:].plot(kind = 'barh')
plt.title('CO2 Emissions Per Capita (1960-2011)')
plt.xlabel('CO2 Emission (Metric Tons)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-236-37291c3bfe95> in <module>()
# ----> 1 by_country['co2_emissions'].sum().order()[-20:].plot(kind = 'barh')
#       2 plt.title('CO2 Emissions Per Capita (1960-2011)')
#       3 plt.xlabel('CO2 Emission (Metric Tons)')
#
# NameError: name 'by_country' is not defined

# %%
climate.pivot_table('occurrence',
                   index = 'year',
                   columns = 'disaster_type',
                   aggfunc='sum').plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-237-cc79dd3d3076> in <module>()
# ----> 1 climate.pivot_table('occurrence',
#       2                    index = 'year',
#       3                    columns = 'disaster_type',
#       4                    aggfunc='sum').plot()
#
# NameError: name 'climate' is not defined

# %%
pt_total_co2.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-238-39263ae20d7c> in <module>()
# ----> 1 pt_total_co2.plot()
#
# NameError: name 'pt_total_co2' is not defined

# %%
pt_total_co2.plot?
# Out:
# Object `pt_total_co2.plot` not found.

# %%
pt_total_co2.plot(figsize=(10, 8))
plt.title('Total CO2 Emissions By Region')
plt.ylabel('CO2 Emission (Metric Tons)')
plt.savefig('total_co2_by_region.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-240-b7b92f8c411c> in <module>()
# ----> 1 pt_total_co2.plot(figsize=(10, 8))
#       2 plt.title('Total CO2 Emissions By Region')
#       3 plt.ylabel('CO2 Emission (Metric Tons)')
#       4 plt.savefig('total_co2_by_region.pdf')
#
# NameError: name 'pt_total_co2' is not defined

# %% [markdown]
# ### Ex: Plot CO2 Emissions Per Capita

# %%
pt_co2_per_cap = climate.pivot_table(values='co2_emissions',
                                    index = 'year',
                                    columns = 'Region',
                                    aggfunc = 'sum',
                                    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-241-df8dfb1aaf02> in <module>()
# ----> 1 pt_co2_per_cap = climate.pivot_table(values='co2_emissions',
#       2                                     index = 'year',
#       3                                     columns = 'Region',
#       4                                     aggfunc = 'sum',
#       5                                     )
#
# NameError: name 'climate' is not defined

# %%
pt_co2_per_cap.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-242-39a3177c70e9> in <module>()
# ----> 1 pt_co2_per_cap.plot()
#
# NameError: name 'pt_co2_per_cap' is not defined

# %%
pt_total_co2.plot(kind = 'box',
                  figsize=(15, 8))
plt.title('Total CO2 Emissions By Region (1960-2011)')
plt.ylabel('CO2 Emission (Metric Tons)')
plt.xticks(rotation= 30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-4c834f83b4bc> in <module>()
# ----> 1 pt_total_co2.plot(kind = 'box',
#       2                   figsize=(15, 8))
#       3 plt.title('Total CO2 Emissions By Region (1960-2011)')
#       4 plt.ylabel('CO2 Emission (Metric Tons)')
#       5 plt.xticks(rotation= 30)
#
# NameError: name 'pt_total_co2' is not defined

# %% [markdown]
# ### Ex: Boxplot Total Damage by Income Group

# %%
pt_deaths_affected_by_income = climate.pivot_table(values='total_death_and_affected',
                                    index = 'year',
                                    columns = 'IncomeGroup',
                                    aggfunc = 'sum',
                                    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-244-fee4b0435c37> in <module>()
# ----> 1 pt_deaths_affected_by_income = climate.pivot_table(values='total_death_and_affected',
#       2                                     index = 'year',
#       3                                     columns = 'IncomeGroup',
#       4                                     aggfunc = 'sum',
#       5                                     )
#
# NameError: name 'climate' is not defined

# %%
pt_deaths_affected_by_income.plot(kind = 'box')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-245-85211bfd063b> in <module>()
# ----> 1 pt_deaths_affected_by_income.plot(kind = 'box')
#
# NameError: name 'pt_deaths_affected_by_income' is not defined

# %%
pt_deaths_affected_by_income.plot(kind = 'bar', stacked = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-246-8c8cb2a18450> in <module>()
# ----> 1 pt_deaths_affected_by_income.plot(kind = 'bar', stacked = True)
#
# NameError: name 'pt_deaths_affected_by_income' is not defined

# %% [markdown]
# ### Scatterplot

# %%
by_year[['Total damage', 'total_co2']].sum().plot(kind ='scatter',
                                                  x = 'total_co2',
                                                  y = 'Total damage',
                                                  xlim = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-247-0c7ac9dd6868> in <module>()
# ----> 1 by_year[['Total damage', 'total_co2']].sum().plot(kind ='scatter',
#       2                                                   x = 'total_co2',
#       3                                                   y = 'Total damage',
#       4                                                   xlim = 0)
#
# NameError: name 'by_year' is not defined

# %% [markdown]
# ## Ex: the relationship between Total CO2 emissions and the occurrence of natural disasters

# %%
# think of how you organize your data first
by_year[['total_co2','occurrence']].sum().plot(kind ='scatter', 
                                               x = 'total_co2',
                                               y = 'occurrence',
                                               xlim = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-248-3f3b618c5020> in <module>()
#       1 # think of how you organize your data first
# ----> 2 by_year[['total_co2','occurrence']].sum().plot(kind ='scatter',
#       3                                                x = 'total_co2',
#       4                                                y = 'occurrence',
#       5                                                xlim = 0)
#
# NameError: name 'by_year' is not defined

# %%
from pandas.tools.plotting import scatter_matrix

# %%
var_by_year = by_year[['total_co2',
                        'occurrence',
                        'Total deaths',
                        'Total affected',
                        ]].sum();
scatter_matrix(var_by_year, alpha = 1.0, figsize=(10, 10))

# %%
scatter_matrix?

# %% [markdown]
# ### Histogram

# %%
climate['Total Population'].plot(kind ='hist')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-249-e5cc8862f986> in <module>()
# ----> 1 climate['Total Population'].plot(kind ='hist')
#
# NameError: name 'climate' is not defined

# %%
# what's the distribution of the occurrence of natural disasters?
climate['occurrence'].plot(kind ='hist')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-250-d0af1c52ddfd> in <module>()
#       1 # what's the distribution of the occurrence of natural disasters?
# ----> 2 climate['occurrence'].plot(kind ='hist')
#
# NameError: name 'climate' is not defined

# %%
# Other Python plotting libraries:
# Seaborn, ggplot for static plotting
# Bokeh for interactive plotting
